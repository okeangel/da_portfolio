# %% [markdown]
# # Географические данные

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Географические-данные" data-toc-modified-id="Географические-данные-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Географические данные</a></span><ul class="toc-item"><li><span><a href="#Как-показать-карту" data-toc-modified-id="Как-показать-карту-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Как показать карту</a></span></li><li><span><a href="#Много-объектов-на-карте" data-toc-modified-id="Много-объектов-на-карте-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Много объектов на карте</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Как показать карту

# %%
# !pip install folium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: folium in c:\users\okean\appdata\roaming\python\python310\site-packages (0.13.0)
# Requirement already satisfied: numpy in c:\users\okean\appdata\roaming\python\python310\site-packages (from folium) (1.22.4)
# Requirement already satisfied: jinja2>=2.9 in c:\program files\python310\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: branca>=0.3.0 in c:\users\okean\appdata\roaming\python\python310\site-packages (from folium) (0.5.0)
# Requirement already satisfied: requests in c:\users\okean\appdata\roaming\python\python310\site-packages (from folium) (2.28.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\program files\python310\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\okean\appdata\roaming\python\python310\site-packages (from requests->folium) (2022.5.18.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\okean\appdata\roaming\python\python310\site-packages (from requests->folium) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\okean\appdata\roaming\python\python310\site-packages (from requests->folium) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\okean\appdata\roaming\python\python310\site-packages (from requests->folium) (2.0.12)
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import folium

# %%
moscow_lat, moscow_lng = 55.751244, 37.618423

# %%
m = folium.Map(location=[moscow_lat, moscow_lng])
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3f19ee36ed174b17706e44eb65d70e74 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3f19ee36ed174b17706e44eb65d70e74&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_3f19ee36ed174b17706e44eb65d70e74 = L.map(
#                 &quot;map_3f19ee36ed174b17706e44eb65d70e74&quot;,
#                 {
#                     center: [55.751244, 37.618423],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1eebaeffcc64d7373372b5371571b20d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3f19ee36ed174b17706e44eb65d70e74);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
display(
    folium.Map(
        location=[moscow_lat, moscow_lng],
        zoom_start=16, tiles='Stamen Terrain'))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_97a47e4e25ada70d801d259dadfa3ea9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_97a47e4e25ada70d801d259dadfa3ea9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_97a47e4e25ada70d801d259dadfa3ea9 = L.map(
#                 &quot;map_97a47e4e25ada70d801d259dadfa3ea9&quot;,
#                 {
#                     center: [55.751244, 37.618423],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ab2287d1dc400b96ddfaea2c6cf97227 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_97a47e4e25ada70d801d259dadfa3ea9);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
bolshoi_theatre_lat, bolshoi_theatre_lng = 55.760082, 37.618668

m = folium.Map(location=[bolshoi_theatre_lat, bolshoi_theatre_lng],
               zoom_start=17)
marker = folium.Marker([bolshoi_theatre_lat, bolshoi_theatre_lng])
marker.add_to(m)
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5ec208d7143c8f6b2ac050741bf11428 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5ec208d7143c8f6b2ac050741bf11428&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5ec208d7143c8f6b2ac050741bf11428 = L.map(
#                 &quot;map_5ec208d7143c8f6b2ac050741bf11428&quot;,
#                 {
#                     center: [55.760082, 37.618668],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2f10d79d605f0bf6564930fd45324ee1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5ec208d7143c8f6b2ac050741bf11428);
#
#
#             var marker_33938332cceb47b1091de40e2dcd6ea3 = L.marker(
#                 [55.760082, 37.618668],
#                 {}
#             ).addTo(map_5ec208d7143c8f6b2ac050741bf11428);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
place_type = 'Театр'

folium.Marker([55.759700, 37.6207130],
              tooltip=place_type,
              popup='Малый театр').add_to(m)
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5ec208d7143c8f6b2ac050741bf11428 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5ec208d7143c8f6b2ac050741bf11428&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5ec208d7143c8f6b2ac050741bf11428 = L.map(
#                 &quot;map_5ec208d7143c8f6b2ac050741bf11428&quot;,
#                 {
#                     center: [55.760082, 37.618668],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2f10d79d605f0bf6564930fd45324ee1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5ec208d7143c8f6b2ac050741bf11428);
#
#
#             var marker_33938332cceb47b1091de40e2dcd6ea3 = L.marker(
#                 [55.760082, 37.618668],
#                 {}
#             ).addTo(map_5ec208d7143c8f6b2ac050741bf11428);
#
#
#             var marker_5546338529ae1cc51c40bc57609ad8c2 = L.marker(
#                 [55.7597, 37.620713],
#                 {}
#             ).addTo(map_5ec208d7143c8f6b2ac050741bf11428);
#
#
#         var popup_89aa387a2316e2783dc9b2ebf3e56ed6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d398c6a89136236fa52d6af13b976ce2 = $(`&lt;div id=&quot;html_d398c6a89136236fa52d6af13b976ce2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Малый театр&lt;/div&gt;`)[0];
#                 popup_89aa387a2316e2783dc9b2ebf3e56ed6.setContent(html_d398c6a89136236fa52d6af13b976ce2);
#
#
#
#         marker_5546338529ae1cc51c40bc57609ad8c2.bindPopup(popup_89aa387a2316e2783dc9b2ebf3e56ed6)
#         ;
#
#
#
#
#             marker_5546338529ae1cc51c40bc57609ad8c2.bindTooltip(
#                 `&lt;div&gt;
#                      Театр
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Много объектов на карте

# %%
import pandas as pd

df = pd.read_csv(
    # shopping centers in Moscow
    'https://code.s3.yandex.net/datasets/moscow_malls_info.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 786 entries, 0 to 785
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      786 non-null    object
#  1   address   786 non-null    object
#  2   hours     685 non-null    object
#  3   lat       786 non-null    float64
#  4   lng       786 non-null    float64
#  5   rating    786 non-null    float64
#  6   district  764 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 43.1+ KB

# %%
m = folium.Map(location=[55.751244, 37.618423])

def create_marker(row):
    folium.Marker([row['lat'], row['lng']],
                  popup=f"{row['name']} {row['rating']}").add_to(m)

df.apply(create_marker, axis=1)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d4592f6dc6687cac6e3e28cabeefab3c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d4592f6dc6687cac6e3e28cabeefab3c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_d4592f6dc6687cac6e3e28cabeefab3c = L.map(
#                 &quot;map_d4592f6dc6687cac6e3e28cabeefab3c&quot;,
#                 {
#                     center: [55.751244, 37.618423],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4fd19d05cbcf1b1020f81731d3585641 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d4592f6dc6687cac6e3e28cabeefab3c);
#
#
#             var marker_bef2738e3f7562a50f44cb4c765cf952 = L.marker(
#                 [55.880803, 37.449824],
#                 {}
#             ).addTo(map_d4592f6dc6687cac6e3e28cabeefab3c);
#
#
#         var popup_65a8a8e83ff3b02090951e608c8c0f30 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f9f7ad842242c65af16cf90940aa895b = $(`&lt;div id=&quot;html_f9f7ad842242c65af16cf90940aa895b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Капитолий 4.7&lt;/div&gt;`)[0];
#                 popup_65a8a8e83ff3b02090951e608c8c0f30.setContent(html_f9f7ad842242c65af16cf90940aa895b);
#
#
#
#         marker_bef2738e3f7562a50f44cb4c765cf952.bindPopup(popup_65a8a8e83ff3b02090951e608c8c0f30)
#         ;
#
#
#
#
#             var marker_2ad7b1b8b596673691cc9b34080a6235 = L.marker(
#                 [55.893082, 37.501263],
#                 {}
#             ).addTo(map_d4592f6dc6687cac6e3e28cabeefab3c);
#
#
#         var popup_87bcf71e32d9192f3d9c74e1ed1f8666 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d89d55fd3326440ecc9a091a660d2a36 = $(`&lt;div id=&quot;html_d89d55fd3326440ecc9a091a660d2a36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dexter 4.3&lt;/div&gt;`)[0];
#                 popup_87bcf71e32d9192f3d9c74e1ed1f8666.setContent(html_d89d55fd3326440ecc9a091a660d2a36);
#
#
#
#         marker_2ad7b1b8b596673691cc9b34080a6235.bindPopup(popup_87bcf71e32d9192f3d9c74e1ed1f8666)
#         ;
#
#
#
#
#             var marker_b4482ebf3712ba478be79256e8330b5e = L.marker(
#                 [55.909388, 37.539546],
#                 {}
#             ).addTo(map_d4592f6dc6687cac6e3e28cabeefab3c);
#
#
#         var popup_58ccb5edea6756a407e541777c30898e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6c7b00ba934e6fbfa8af60828aa0b890 = $(`&lt;div id=&quot;html_6c7b00ba934e6fbfa8af60828aa0b890&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;РИО 4.8&lt;/div&gt;`)[0];
#                 popup_58ccb5edea6756a407e541777c30898e.setContent(html_6c7b00ba934e6fbfa8af60828aa0b890);
#
#
#
#         marker_b4482ebf3712ba478be79256e8330b5e.bindPopup(popup_58ccb5edea6756a407e541777c30898e)
#         ;
#
#
#
#
#             var marker_7037ca94c4d043a6b4ad01ed34229e1f = L.marker(
#                 [55.869937, 37.469915],
#                 {}
#             ).addTo(map_d4592f6dc6687cac6e3e28cabeefab3c);
#
#
#         var popup_1152ace487f16ea5ece8d60c8758cb39 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b71afd0c0fdfbe5d32f6430dabf37b5c = $(`&lt;div id=&quot;html_b71afd0c0fdfbe5d32f6430dabf37b5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Экстрим 4.7&lt;/div&gt;`)[0];
#                 popup_1152ace487f16ea5ece8d60c8758cb39.setContent(html_b71afd0c0fdfbe5d32f6430dabf37b5c);
#
#
#
#         marker_7037ca94c4d043a6b4ad01ed34229e1f.bindPopup(popup_1152ace487f16ea5ece8d60c8758cb39)
#         ;
#
#
#
#
#             var marker_c256049f8ba9aec17afdd39586f7c2eb = L.marker(
#                 [55.878662, 37.479251],
#                 {}
#             ).addTo(map_d4592f6dc6687cac6e3e28cabeefab3c);
#
#
#         var popup_ba3487f51462203f683cc7a4a019beff = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_117364470a4c1b0ad093e68f57769583 = $(`&lt;div id=&quot;html_117364470a4c1b0ad093e68f57769583&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Discovery 4.3&lt;/div&gt;`)[0];
#                 popup_ba3487f51462203f683cc7a4a019beff.setContent(html_117364470a4c1b0ad093e68f57769583);
#
#
#
#         marker_c256049f8ba9aec17afdd39586f7c2eb.bindPopup(popup_ba3487f51462203f683cc7a4a019beff)
#         ;
#
#
#
#
#             var marker_987ce442aa38d3127deab86ae032643d = L.marker(
#                 [55.893181, 37.50108],
#                 {}
#             ).addTo(map_d4592f6dc6687cac6e3e28cabeefab3c);
#
#
#         var popup_06cc67f4656c7257eabd2e5444918cfa = L.popup({&quot;maxWid

# %% [markdown]
# Здесь могут возникнуть проблемы:
#
# Карта может долго отрисовываться, или рендериться (от англ. render, «выводить, отображать»), на слабых по производительности компьютерах или серверах;
# Если на карте много точек, при уменьшении масштаба в ней будет сложно ориентироваться.
# Из-за высокой нагрузки карта может зависать при передвижении по ней.
# Если отобразить на карте несколько тысяч точек, эти проблемы станут особенно заметны. Помогут кластеры — с их помощью можно поместить на карту много маркеров одновременно.
#
# Отметим все торговые центры на карте с помощью кластеров:

# %%
m = folium.Map(location=[moscow_lat, moscow_lng])

import folium.plugins

marker_cluster = folium.plugins.MarkerCluster().add_to(m)

def create_clusters(row):
    folium.Marker(
        [row['lat'], row['lng']],
        popup=f"{row['name']} {row['rating']}",
    ).add_to(marker_cluster)

df.apply(create_clusters, axis=1)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f45b7a74fd1e0d2f563469fa50d6a4f4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f45b7a74fd1e0d2f563469fa50d6a4f4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_f45b7a74fd1e0d2f563469fa50d6a4f4 = L.map(
#                 &quot;map_f45b7a74fd1e0d2f563469fa50d6a4f4&quot;,
#                 {
#                     center: [55.751244, 37.618423],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5ea4d87fc1c3055d4f7a7e1ed1f0e6e9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f45b7a74fd1e0d2f563469fa50d6a4f4);
#
#
#             var marker_cluster_d8a5f75faf246341c13c6268a9e41b68 = L.markerClusterGroup(
#                 {}
#             );
#             map_f45b7a74fd1e0d2f563469fa50d6a4f4.addLayer(marker_cluster_d8a5f75faf246341c13c6268a9e41b68);
#
#
#             var marker_36aa5ffd1c2ce68fdd427ab65f846aac = L.marker(
#                 [55.880803, 37.449824],
#                 {}
#             ).addTo(marker_cluster_d8a5f75faf246341c13c6268a9e41b68);
#
#
#         var popup_e55a0695e22a9b9582c941cae4c60091 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d6e973352ddb34c9e97a2c2f45433fa6 = $(`&lt;div id=&quot;html_d6e973352ddb34c9e97a2c2f45433fa6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Капитолий 4.7&lt;/div&gt;`)[0];
#                 popup_e55a0695e22a9b9582c941cae4c60091.setContent(html_d6e973352ddb34c9e97a2c2f45433fa6);
#
#
#
#         marker_36aa5ffd1c2ce68fdd427ab65f846aac.bindPopup(popup_e55a0695e22a9b9582c941cae4c60091)
#         ;
#
#
#
#
#             var marker_e61b72d8c261c93d7f2e3acaab548e71 = L.marker(
#                 [55.893082, 37.501263],
#                 {}
#             ).addTo(marker_cluster_d8a5f75faf246341c13c6268a9e41b68);
#
#
#         var popup_9d91398a75ad3bf1f207f8fa5f018bf9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a457a7981413c96ecc3da6dd21ec2e15 = $(`&lt;div id=&quot;html_a457a7981413c96ecc3da6dd21ec2e15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dexter 4.3&lt;/div&gt;`)[0];
#                 popup_9d91398a75ad3bf1f207f8fa5f018bf9.setContent(html_a457a7981413c96ecc3da6dd21ec2e15);
#
#
#
#         marker_e61b72d8c261c93d7f2e3acaab548e71.bindPopup(popup_9d91398a75ad3bf1f207f8fa5f018bf9)
#         ;
#
#
#
#
#             var marker_b6b6ffd0752df741eff12e31ab204678 = L.marker(
#                 [55.909388, 37.539546],
#                 {}
#             ).addTo(marker_cluster_d8a5f75faf246341c13c6268a9e41b68);
#
#
#         var popup_4ea4bf277a0bdf27982141e4dae9ca90 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5e9ece7ad83136dad3ed1a8904f5fc85 = $(`&lt;div id=&quot;html_5e9ece7ad83136dad3ed1a8904f5fc85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;РИО 4.8&lt;/div&gt;`)[0];
#                 popup_4ea4bf277a0bdf27982141e4dae9ca90.setContent(html_5e9ece7ad83136dad3ed1a8904f5fc85);
#
#
#
#         marker_b6b6ffd0752df741eff12e31ab204678.bindPopup(popup_4ea4bf277a0bdf27982141e4dae9ca90)
#         ;
#
#
#
#
#             var marker_d7f5619407414110edf1b9c49e33c504 = L.marker(
#                 [55.869937, 37.469915],
#                 {}
#             ).addTo(marker_cluster_d8a5f75faf246341c13c6268a9e41b68);
#
#
#         var popup_9b4a0725bbf9ed3127cd8500d8069547 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9a44b9daa66680a81176030565aaf4a3 = $(`&lt;div id=&quot;html_9a44b9daa66680a81176030565aaf4a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Экстрим 4.7&lt;/div&gt;`)[0];
#                 popup_9b4a0725bbf9ed3127cd8500d8069547.setContent(html_9a44b9daa66680a81176030565aaf4a3);
#
#
#
#         marker_d7f5619407414110edf1b9c49e33c504.bindPopup(popup_9b4a0725bbf9ed3127cd8500d8069547)
#         ;
#
#
#
#
#             var marker_a799ac19c07b3dbced09e1fb434c124d = L.marker(
#                 [55.878662, 37.479251],
#                 {}
#             ).addTo(marker_cluster_d8a5f75faf246341c13c6268a9e41b68);
#
#
#         var popup_f1c160d243a29d8ed6278503014b9eab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
