# %% [markdown]
# # Географические данные

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Географические-данные" data-toc-modified-id="Географические-данные-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Географические данные</a></span><ul class="toc-item"><li><span><a href="#Как-показать-карту" data-toc-modified-id="Как-показать-карту-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Как показать карту</a></span></li><li><span><a href="#Много-объектов-на-карте" data-toc-modified-id="Много-объектов-на-карте-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Много объектов на карте</a></span></li><li><span><a href="#Собственные-иконки" data-toc-modified-id="Собственные-иконки-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Собственные иконки</a></span></li><li><span><a href="#Картограммы-(диаграммы-на-картах)" data-toc-modified-id="Картограммы-(диаграммы-на-картах)-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Картограммы (диаграммы на картах)</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Как показать карту

# %%
import folium

# %%
moscow_lat, moscow_lng = 55.751244, 37.618423

# %%
m = folium.Map(location=[moscow_lat, moscow_lng])
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_db2ad5b9277bd48c9d0dbaa05800ba7b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_db2ad5b9277bd48c9d0dbaa05800ba7b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_db2ad5b9277bd48c9d0dbaa05800ba7b = L.map(
#                 &quot;map_db2ad5b9277bd48c9d0dbaa05800ba7b&quot;,
#                 {
#                     center: [55.751244, 37.618423],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_31cc635916ed6127abfc9eeb5a2620b8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_db2ad5b9277bd48c9d0dbaa05800ba7b);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
display(
    folium.Map(
        location=[moscow_lat, moscow_lng],
        zoom_start=16,
        tiles='Stamen Terrain',
    )
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f7b3c44eb557dbe11b77edbb2beeaf6b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f7b3c44eb557dbe11b77edbb2beeaf6b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_f7b3c44eb557dbe11b77edbb2beeaf6b = L.map(
#                 &quot;map_f7b3c44eb557dbe11b77edbb2beeaf6b&quot;,
#                 {
#                     center: [55.751244, 37.618423],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0d2aa9925b61aa61d0e93f0795b552b6 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f7b3c44eb557dbe11b77edbb2beeaf6b);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
bolshoi_theatre_lat, bolshoi_theatre_lng = 55.760082, 37.618668

m = folium.Map(
    location=[bolshoi_theatre_lat, bolshoi_theatre_lng], zoom_start=17
)
marker = folium.Marker([bolshoi_theatre_lat, bolshoi_theatre_lng])
marker.add_to(m)
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5eb0535f421794b3708f9b67cee2e09f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5eb0535f421794b3708f9b67cee2e09f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5eb0535f421794b3708f9b67cee2e09f = L.map(
#                 &quot;map_5eb0535f421794b3708f9b67cee2e09f&quot;,
#                 {
#                     center: [55.760082, 37.618668],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d6ea203dc7272c59dbf7e9fca7db64fe = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5eb0535f421794b3708f9b67cee2e09f);
#
#
#             var marker_4036ab110aa096b78690bf29fc01d858 = L.marker(
#                 [55.760082, 37.618668],
#                 {}
#             ).addTo(map_5eb0535f421794b3708f9b67cee2e09f);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
place_type = 'Театр'

folium.Marker(
    [55.759700, 37.6207130], tooltip=place_type, popup='Малый театр'
).add_to(m)
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5eb0535f421794b3708f9b67cee2e09f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5eb0535f421794b3708f9b67cee2e09f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5eb0535f421794b3708f9b67cee2e09f = L.map(
#                 &quot;map_5eb0535f421794b3708f9b67cee2e09f&quot;,
#                 {
#                     center: [55.760082, 37.618668],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d6ea203dc7272c59dbf7e9fca7db64fe = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5eb0535f421794b3708f9b67cee2e09f);
#
#
#             var marker_4036ab110aa096b78690bf29fc01d858 = L.marker(
#                 [55.760082, 37.618668],
#                 {}
#             ).addTo(map_5eb0535f421794b3708f9b67cee2e09f);
#
#
#             var marker_c569a173d6a8c9b2bc40bf474f069aa5 = L.marker(
#                 [55.7597, 37.620713],
#                 {}
#             ).addTo(map_5eb0535f421794b3708f9b67cee2e09f);
#
#
#         var popup_07b0c42d0f4bfd164c626cf5f5f0cf82 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dedbad42a1d88ef63fbfba2a7bb34f7c = $(`&lt;div id=&quot;html_dedbad42a1d88ef63fbfba2a7bb34f7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Малый театр&lt;/div&gt;`)[0];
#                 popup_07b0c42d0f4bfd164c626cf5f5f0cf82.setContent(html_dedbad42a1d88ef63fbfba2a7bb34f7c);
#
#
#
#         marker_c569a173d6a8c9b2bc40bf474f069aa5.bindPopup(popup_07b0c42d0f4bfd164c626cf5f5f0cf82)
#         ;
#
#
#
#
#             marker_c569a173d6a8c9b2bc40bf474f069aa5.bindTooltip(
#                 `&lt;div&gt;
#                      Театр
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Много объектов на карте

# %%
import pandas as pd

DATA_HOST_URL = 'https://code.s3.yandex.net'

df = pd.read_csv(
    # shopping centers in Moscow
    DATA_HOST_URL
    + '/datasets/moscow_malls_info.csv'
)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 786 entries, 0 to 785
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      786 non-null    object
#  1   address   786 non-null    object
#  2   hours     685 non-null    object
#  3   lat       786 non-null    float64
#  4   lng       786 non-null    float64
#  5   rating    786 non-null    float64
#  6   district  764 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 43.1+ KB

# %%
m = folium.Map(location=[55.751244, 37.618423])


def create_marker(row):
    folium.Marker(
        [row['lat'], row['lng']], popup=f"{row['name']} {row['rating']}"
    ).add_to(m)


df.apply(create_marker, axis=1)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_65af3aca77ff7525e8d1f61e446d48fd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_65af3aca77ff7525e8d1f61e446d48fd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_65af3aca77ff7525e8d1f61e446d48fd = L.map(
#                 &quot;map_65af3aca77ff7525e8d1f61e446d48fd&quot;,
#                 {
#                     center: [55.751244, 37.618423],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_01b5011a86f6c9754deedee0ef6951c1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_65af3aca77ff7525e8d1f61e446d48fd);
#
#
#             var marker_2cb0f72bcfd1b0c9f0853897c3fb5a14 = L.marker(
#                 [55.880803, 37.449824],
#                 {}
#             ).addTo(map_65af3aca77ff7525e8d1f61e446d48fd);
#
#
#         var popup_a7b1cf06a3e1d730f0bb59145ac71954 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_56f9f335bec60c984f644c9fe445c04e = $(`&lt;div id=&quot;html_56f9f335bec60c984f644c9fe445c04e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Капитолий 4.7&lt;/div&gt;`)[0];
#                 popup_a7b1cf06a3e1d730f0bb59145ac71954.setContent(html_56f9f335bec60c984f644c9fe445c04e);
#
#
#
#         marker_2cb0f72bcfd1b0c9f0853897c3fb5a14.bindPopup(popup_a7b1cf06a3e1d730f0bb59145ac71954)
#         ;
#
#
#
#
#             var marker_98970f9a78f2c0c378748d4651e468ad = L.marker(
#                 [55.893082, 37.501263],
#                 {}
#             ).addTo(map_65af3aca77ff7525e8d1f61e446d48fd);
#
#
#         var popup_bd057fd2d946b21e208510f75d03b014 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_852cfa5beef412cde8f7ea69d293e7e9 = $(`&lt;div id=&quot;html_852cfa5beef412cde8f7ea69d293e7e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dexter 4.3&lt;/div&gt;`)[0];
#                 popup_bd057fd2d946b21e208510f75d03b014.setContent(html_852cfa5beef412cde8f7ea69d293e7e9);
#
#
#
#         marker_98970f9a78f2c0c378748d4651e468ad.bindPopup(popup_bd057fd2d946b21e208510f75d03b014)
#         ;
#
#
#
#
#             var marker_009c270e6fdd1fbbff69e0042d011262 = L.marker(
#                 [55.909388, 37.539546],
#                 {}
#             ).addTo(map_65af3aca77ff7525e8d1f61e446d48fd);
#
#
#         var popup_2375efb1a4dbc60b72f9cee923a683e5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8e4d9111d64637c3231eef144b173695 = $(`&lt;div id=&quot;html_8e4d9111d64637c3231eef144b173695&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;РИО 4.8&lt;/div&gt;`)[0];
#                 popup_2375efb1a4dbc60b72f9cee923a683e5.setContent(html_8e4d9111d64637c3231eef144b173695);
#
#
#
#         marker_009c270e6fdd1fbbff69e0042d011262.bindPopup(popup_2375efb1a4dbc60b72f9cee923a683e5)
#         ;
#
#
#
#
#             var marker_05003647807bba17b5cc9490c39eb12d = L.marker(
#                 [55.869937, 37.469915],
#                 {}
#             ).addTo(map_65af3aca77ff7525e8d1f61e446d48fd);
#
#
#         var popup_5e1eb379cb12ad11137a4a1e9bd77c84 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1f0ac059aaa3c6ccc8c08ee78bf73893 = $(`&lt;div id=&quot;html_1f0ac059aaa3c6ccc8c08ee78bf73893&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Экстрим 4.7&lt;/div&gt;`)[0];
#                 popup_5e1eb379cb12ad11137a4a1e9bd77c84.setContent(html_1f0ac059aaa3c6ccc8c08ee78bf73893);
#
#
#
#         marker_05003647807bba17b5cc9490c39eb12d.bindPopup(popup_5e1eb379cb12ad11137a4a1e9bd77c84)
#         ;
#
#
#
#
#             var marker_2e12e9e2c1823e58aa0178f3e23690d8 = L.marker(
#                 [55.878662, 37.479251],
#                 {}
#             ).addTo(map_65af3aca77ff7525e8d1f61e446d48fd);
#
#
#         var popup_c76c01e0cf67d49aeaadbf866bc06692 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4878004c469374ca48b75b168f8418c9 = $(`&lt;div id=&quot;html_4878004c469374ca48b75b168f8418c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Discovery 4.3&lt;/div&gt;`)[0];
#                 popup_c76c01e0cf67d49aeaadbf866bc06692.setContent(html_4878004c469374ca48b75b168f8418c9);
#
#
#
#         marker_2e12e9e2c1823e58aa0178f3e23690d8.bindPopup(popup_c76c01e0cf67d49aeaadbf866bc06692)
#         ;
#
#
#
#
#             var marker_12edf461693fa67b714d966d21b39215 = L.marker(
#                 [55.893181, 37.50108],
#                 {}
#             ).addTo(map_65af3aca77ff7525e8d1f61e446d48fd);
#
#
#         var popup_97d7be790587c6b6c156e493bef09a3e = L.popup({&quot;maxWid

# %% [markdown]
# Здесь могут возникнуть проблемы:
#
# Карта может долго отрисовываться, или рендериться (от англ. render, «выводить, отображать»), на слабых по производительности компьютерах или серверах;
# Если на карте много точек, при уменьшении масштаба в ней будет сложно ориентироваться.
# Из-за высокой нагрузки карта может зависать при передвижении по ней.
# Если отобразить на карте несколько тысяч точек, эти проблемы станут особенно заметны. Помогут кластеры — с их помощью можно поместить на карту много маркеров одновременно.
#
# Отметим все торговые центры на карте с помощью кластеров:

# %%
m = folium.Map(location=[moscow_lat, moscow_lng])

import folium.plugins

marker_cluster = folium.plugins.MarkerCluster().add_to(m)


def add_to_cluster(row):
    folium.Marker(
        [row['lat'], row['lng']],
        popup=f"{row['name']} {row['rating']}",
    ).add_to(marker_cluster)


df.apply(add_to_cluster, axis=1)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_39be3f93cc542dd52dc4b88b86b188d9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_39be3f93cc542dd52dc4b88b86b188d9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_39be3f93cc542dd52dc4b88b86b188d9 = L.map(
#                 &quot;map_39be3f93cc542dd52dc4b88b86b188d9&quot;,
#                 {
#                     center: [55.751244, 37.618423],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_51fe300efd4f9f22a3b90061cad9de3f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_39be3f93cc542dd52dc4b88b86b188d9);
#
#
#             var marker_cluster_aa58a0c839d8e02fd42ea43ab288e58d = L.markerClusterGroup(
#                 {}
#             );
#             map_39be3f93cc542dd52dc4b88b86b188d9.addLayer(marker_cluster_aa58a0c839d8e02fd42ea43ab288e58d);
#
#
#             var marker_42ced4345e4988f5c4f3663c8d11d4c8 = L.marker(
#                 [55.880803, 37.449824],
#                 {}
#             ).addTo(marker_cluster_aa58a0c839d8e02fd42ea43ab288e58d);
#
#
#         var popup_a03064389b88dd024e7d530b6316b075 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_850422f08b7f7a37d07ef277cdb7aba9 = $(`&lt;div id=&quot;html_850422f08b7f7a37d07ef277cdb7aba9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Капитолий 4.7&lt;/div&gt;`)[0];
#                 popup_a03064389b88dd024e7d530b6316b075.setContent(html_850422f08b7f7a37d07ef277cdb7aba9);
#
#
#
#         marker_42ced4345e4988f5c4f3663c8d11d4c8.bindPopup(popup_a03064389b88dd024e7d530b6316b075)
#         ;
#
#
#
#
#             var marker_a2b0c65e8eb6ebf4dba3d8dbc484638f = L.marker(
#                 [55.893082, 37.501263],
#                 {}
#             ).addTo(marker_cluster_aa58a0c839d8e02fd42ea43ab288e58d);
#
#
#         var popup_ebd4157aab14c49b7daf4c3391d355c6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9eceef7769db3ab722faee06ad9f99a2 = $(`&lt;div id=&quot;html_9eceef7769db3ab722faee06ad9f99a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dexter 4.3&lt;/div&gt;`)[0];
#                 popup_ebd4157aab14c49b7daf4c3391d355c6.setContent(html_9eceef7769db3ab722faee06ad9f99a2);
#
#
#
#         marker_a2b0c65e8eb6ebf4dba3d8dbc484638f.bindPopup(popup_ebd4157aab14c49b7daf4c3391d355c6)
#         ;
#
#
#
#
#             var marker_ad35683d3caf694aa73960dd657da508 = L.marker(
#                 [55.909388, 37.539546],
#                 {}
#             ).addTo(marker_cluster_aa58a0c839d8e02fd42ea43ab288e58d);
#
#
#         var popup_358f19ac04ef7745994d1bc0a8d916eb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a65bc701274b55e57a597aa4f4070250 = $(`&lt;div id=&quot;html_a65bc701274b55e57a597aa4f4070250&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;РИО 4.8&lt;/div&gt;`)[0];
#                 popup_358f19ac04ef7745994d1bc0a8d916eb.setContent(html_a65bc701274b55e57a597aa4f4070250);
#
#
#
#         marker_ad35683d3caf694aa73960dd657da508.bindPopup(popup_358f19ac04ef7745994d1bc0a8d916eb)
#         ;
#
#
#
#
#             var marker_9ff4f191ef55e35f34b99c38dff5b38b = L.marker(
#                 [55.869937, 37.469915],
#                 {}
#             ).addTo(marker_cluster_aa58a0c839d8e02fd42ea43ab288e58d);
#
#
#         var popup_0d19d9b17fb94c728263305420a0ffb9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f65b1b5d0ed7c1ac2414db44d7c0da81 = $(`&lt;div id=&quot;html_f65b1b5d0ed7c1ac2414db44d7c0da81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Экстрим 4.7&lt;/div&gt;`)[0];
#                 popup_0d19d9b17fb94c728263305420a0ffb9.setContent(html_f65b1b5d0ed7c1ac2414db44d7c0da81);
#
#
#
#         marker_9ff4f191ef55e35f34b99c38dff5b38b.bindPopup(popup_0d19d9b17fb94c728263305420a0ffb9)
#         ;
#
#
#
#
#             var marker_d05aa2071b169b77327ae7402abda0c6 = L.marker(
#                 [55.878662, 37.479251],
#                 {}
#             ).addTo(marker_cluster_aa58a0c839d8e02fd42ea43ab288e58d);
#
#
#         var popup_4e021afbd6d9b2ef0bbc6b4b77f94b93 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});

# %% [markdown]
# ## Собственные иконки

# %%
m = folium.Map(location=[moscow_lat, moscow_lng])
marker_cluster = folium.plugins.MarkerCluster().add_to(m)

import folium.features
from folium import Marker

icon_url = (
    'https://img.icons8.com/external-wanicon-flat-wanicon/344/'
    'external-mall-shop-and-store-wanicon-flat-wanicon.png'
)


def add_with_icon_to_cluster(row):
    Marker(
        [row['lat'], row['lng']],
        popup=f"{row['name']} {row['rating']}",
        # создавать иконку нужно каждый раз зановоdistrict_poly
        icon=folium.features.CustomIcon(icon_url, icon_size=(30, 30)),
    ).add_to(marker_cluster)


df.apply(add_with_icon_to_cluster, axis=1)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2427df189db1ef66fb2f569c238cd5ab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2427df189db1ef66fb2f569c238cd5ab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_2427df189db1ef66fb2f569c238cd5ab = L.map(
#                 &quot;map_2427df189db1ef66fb2f569c238cd5ab&quot;,
#                 {
#                     center: [55.751244, 37.618423],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ed9a572f5f7caa2bf72b9a5b1ca7fc85 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2427df189db1ef66fb2f569c238cd5ab);
#
#
#             var marker_cluster_e7c45bd6e12a5293c38fd0b0063d8b03 = L.markerClusterGroup(
#                 {}
#             );
#             map_2427df189db1ef66fb2f569c238cd5ab.addLayer(marker_cluster_e7c45bd6e12a5293c38fd0b0063d8b03);
#
#
#             var marker_f1fd7bd95dde6877eeb13238fcbf6f17 = L.marker(
#                 [55.880803, 37.449824],
#                 {}
#             ).addTo(marker_cluster_e7c45bd6e12a5293c38fd0b0063d8b03);
#
#
#         var custom_icon_a7f7db03fb160e5b8350238fd9d2b617 = L.icon({&quot;iconSize&quot;: [30, 30], &quot;iconUrl&quot;: &quot;https://img.icons8.com/external-wanicon-flat-wanicon/344/external-mall-shop-and-store-wanicon-flat-wanicon.png&quot;});
#         marker_f1fd7bd95dde6877eeb13238fcbf6f17.setIcon(custom_icon_a7f7db03fb160e5b8350238fd9d2b617);
#
#
#         var popup_cfe77c7aa92a980859dad093f75c52c0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3796f53936b156b3f1c8e1c3b3e7f1b3 = $(`&lt;div id=&quot;html_3796f53936b156b3f1c8e1c3b3e7f1b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Капитолий 4.7&lt;/div&gt;`)[0];
#                 popup_cfe77c7aa92a980859dad093f75c52c0.setContent(html_3796f53936b156b3f1c8e1c3b3e7f1b3);
#
#
#
#         marker_f1fd7bd95dde6877eeb13238fcbf6f17.bindPopup(popup_cfe77c7aa92a980859dad093f75c52c0)
#         ;
#
#
#
#
#             var marker_6f44679dd60c4ebd74e9e57350a733ca = L.marker(
#                 [55.893082, 37.501263],
#                 {}
#             ).addTo(marker_cluster_e7c45bd6e12a5293c38fd0b0063d8b03);
#
#
#         var custom_icon_cc810c1c2d042a497ada4640f0d20b64 = L.icon({&quot;iconSize&quot;: [30, 30], &quot;iconUrl&quot;: &quot;https://img.icons8.com/external-wanicon-flat-wanicon/344/external-mall-shop-and-store-wanicon-flat-wanicon.png&quot;});
#         marker_6f44679dd60c4ebd74e9e57350a733ca.setIcon(custom_icon_cc810c1c2d042a497ada4640f0d20b64);
#
#
#         var popup_d2443b5ec504cdbe01f9f27505715645 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_26b95c77839a2f4c5663477b8f2406ce = $(`&lt;div id=&quot;html_26b95c77839a2f4c5663477b8f2406ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dexter 4.3&lt;/div&gt;`)[0];
#                 popup_d2443b5ec504cdbe01f9f27505715645.setContent(html_26b95c77839a2f4c5663477b8f2406ce);
#
#
#
#         marker_6f44679dd60c4ebd74e9e57350a733ca.bindPopup(popup_d2443b5ec504cdbe01f9f27505715645)
#         ;
#
#
#
#
#             var marker_2f6a60c844ff363b8a03d35101b769b9 = L.marker(
#                 [55.909388, 37.539546],
#                 {}
#             ).addTo(marker_cluster_e7c45bd6e12a5293c38fd0b0063d8b03);
#
#
#         var custom_icon_5dd5f0e8826974eb6e66f9d30b5f8dc6 = L.icon({&quot;iconSize&quot;: [30, 30], &quot;iconUrl&quot;: &quot;https://img.icons8.com/external-wanicon-flat-wanicon/344/external-mall-shop-and-store-wanicon-flat-wanicon.png&quot;});
#         marker_2f6a60c844ff363b8a03d35101b769b9.setIcon(custom_icon_5dd5f0e8826974eb6e66f9d30b5f8dc6);
#
#
#         var popup_e4de1382335d13508326c0d284dffc36 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_06298fda14394baa25aaf30832d9e718 = $(`&lt;div id=&quot;html_06298fda14394baa25aaf30832d9e718&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;РИО 4.8&lt;/div&gt;`)[0];
#                 popup_e4de1382335d13508326c0d284dffc36.setContent(html_06298fda14394baa25aaf30832d9e718);
#
#
#
#         marker_2f6a60c844ff363b8a03d35101b769b9.bindPopup(popup_e4de1382335d13508326c0d284dffc36)
#         ;
#
#
#
#
#             var marker_4c58ca50d0034027f5f219

# %% [markdown]
# ## Картограммы (диаграммы на картах)

# %%
df['district'].unique()
# Out:
# array(['Северный административный округ',
#        'Северо-Восточный административный округ', nan,
#        'Северо-Западный административный округ',
#        'Восточный административный округ',
#        'Западный административный округ',
#        'Центральный административный округ',
#        'Южный административный округ',
#        'Юго-Восточный административный округ',
#        'Юго-Западный административный округ'], dtype=object)

# %%
rating_df = df.groupby('district', as_index=False)['rating'].agg('median')
rating_df
# Out:
#                                   district  rating
# 0         Восточный административный округ     4.0
# 1          Западный административный округ     4.2
# 2          Северный административный округ     4.2
# 3  Северо-Восточный административный округ     4.1
# 4   Северо-Западный административный округ     4.0
# 5       Центральный административный округ     4.1
# 6     Юго-Восточный административный округ     4.0
# 7      Юго-Западный административный округ     4.3
# 8             Южный административный округ     4.2

# %% [markdown]
# Чтобы отобразить округа на карте, folium нужно передать границы каждой области. Для этого можно использовать особый текстовый файл в формате GeoJSON. Файл содержит JSON-описание точек, линий (цепочек точек), полигонов (замкнутых цепочек точек). Каждая точка - это координата в виде "(latitude, longitude)".
#
# Обычно GeoJSON-файлы нужных регионов можно найти в интернете.

# %%
import json
import urllib

district_boundaries = json.loads(
    urllib.request.urlopen(
        'https://code.s3.yandex.net/data-analyst/admin_level_geomap.geojson'
    ).read()
)

# %%
# создаём карту Москвы
m = folium.Map(location=[moscow_lat, moscow_lng], zoom_start=10)

# создаём хороплет с помощью конструктора Choropleth и добавляем его на карту
folium.Choropleth(
    geo_data=district_boundaries,
    data=rating_df,
    columns=['district', 'rating'],
    key_on='feature.name',
    fill_color='YlGn',
    fill_opacity=0.8,
    legend_name='Медианный рейтинг заведений по районам',
).add_to(m)

# выводим карту
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a0f698efb27a11b8f6d4e943ade30ab6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a0f698efb27a11b8f6d4e943ade30ab6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_a0f698efb27a11b8f6d4e943ade30ab6 = L.map(
#                 &quot;map_a0f698efb27a11b8f6d4e943ade30ab6&quot;,
#                 {
#                     center: [55.751244, 37.618423],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8c5e2fde2af680c6c2f8cf5dded980e2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a0f698efb27a11b8f6d4e943ade30ab6);
#
#
#             var choropleth_a5c8de9f94b3c3ed0bc2a4b7cb61d10e = L.featureGroup(
#                 {}
#             ).addTo(map_a0f698efb27a11b8f6d4e943ade30ab6);
#
#
#         function geo_json_50b4886d15afd58f5fd05f87f7411f79_styler(feature) {
#             switch(feature.id) {
#                 case 162903: case 1282181: case 226149:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#31a354&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case 1304596:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006837&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case 1252558: case 2162196:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#addd8e&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_50b4886d15afd58f5fd05f87f7411f79_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_50b4886d15afd58f5fd05f87f7411f79 = L.geoJson(null, {
#                 onEachFeature: geo_json_50b4886d15afd58f5fd05f87f7411f79_onEachFeature,
#
#                 style: geo_json_50b4886d15afd58f5fd05f87f7411f79_styler,
#         });
#
#         function geo_json_50b4886d15afd58f5fd05f87f7411f79_add (data) {
#             geo_json_50b4886d15afd58f5fd05f87f7411f79
#                 .addData(data)
#                 .addTo(choropleth_a5c8de9f94b3c3ed0bc2a4b7cb61d10e);
#         }
#             geo_json_50b4886d15afd58f5fd05f87f7411f79_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[37.8756653, 55.825342400000004], [37.876001599999995, 55.8249027], [37.8730967, 55.8237936], [37.8689418, 55.8228697], [37.869206999999996, 55.822363200000005], [37.868322500000005, 55.822211100000004], [37.867472, 55.823703], [37.86851090000001, 55.82391880000001], [37.87046039999999, 55.8242706], [37.871727799999995, 55.8246505], [37.8724412, 55.824851499999994], [37.873601099999995, 55.8251836], [37.874401799999994, 55.8252441], [37.8748787, 55.825267399999994], [37.8756653, 55.825342400000004]]], [[[37.797732300000014, 55.99985], [37.79532840000001, 55.9990248], [37.793020500000004, 56.0011418], [37.792486800000006, 56.0009504], [37.79018290000001, 56.0001243], [37.7887247, 56.0013886], [37.791381200000004, 56.002270100000004], [37.79097720000001, 56.0026548], [37.79033860000001, 56.00251240000001], [37.79001420000001, 56.002850200000005], [37.791075500000005, 56.0032236], [37.79213700000001, 56.003597], [37.79290810000001, 56.0038699], [37.793034600000006, 56.0037881], [37.79353240000001, 56.0037672], [37.79415630000001, 56.003185300000005], [37.797732300000014, 55.99985]]], [[[37.79895800000001, 56.009590100000004], [37.79812700000001, 56.007685099999996], [37.7986646, 56.0068026], [37.79950730000001, 56.006109900000006], [37.797426900000005, 56.0053804], [37.7968617, 56.0046327], [37.7936914, 56.005357800000006], [37.793098500000006, 56.0055271], [37.791304000000004, 56.0071472], [37.791591100000005, 56.0074532], [37.7932241, 56.0080698], [37.79301430000001, 56.00823260000001], [37.795332000000016, 56.00899870000001], [37.7949344, 56.0092902], [37.7979841, 56.00953210000001], [37.79853170000001, 56.0096683], [37.7988895, 56.0096066], [37.79895800000001, 56.009590100000004]]], [[[37.899785200000004, 55.8161364], [37.8999346, 55.8151406], [37.8994626, 55.8145828], [37.897964699999996, 55.813788499999994], [37.8972371, 55.813656599999995], [37.896656300000004, 55.81365039999999], [37.8960238, 55.813732], [37.895435000000006, 55.81376039999999], [37.8943798, 55.813931499999995], [37.8930571, 55.81422599999999], [37.892053700000005, 55.814827399999984], [37.8914232, 55.815043599999996],

# %% [markdown]
# У конструктора `Choropleth()` много параметров:
#
# - `geo_data` — строка, которая содержит путь к GeoJSON-файлу с информацией о границах регионов. Обратите внимание: читать или обрабатывать файл для построения хороплета не требуется.
# - `data` — датафрейм, который, помимо прочего, содержит геоданные — информацию о широте и долготе точек.
# - `columns` — список столбцов датафрейма из `data`, которые нужно использовать при построении фоновой картограммы.
# - `key_on` — строка, которая содержит название нужного ключа в JSON, например с названием региона. В начале строки указывают `feature.`, а затем название ключа. В GeoJSON-файле с данными Москвы названия округов хранятся в ключе `name`, поэтому достаточно передать параметру `key_on` строку `'feature.name'`. Библиотека найдёт ключ в JSON, достанет соответствующее ему значение и сопоставит его со строками датафрейма `data`.
# - `fill_color` — строка, которая задаёт цветовую схему хороплета. Мы использовали схему `YlGn`, которая содержит жёлтые (англ. yellow) и зелёные (англ. green) цвета и их оттенки. Цветовая схема может быть следующей:
# ![fillcolors_image](https://code.s3.yandex.net/data-analyst/new_images/sphx_glr_colormap_reference_002_2_0x%20(1).webp)
# - `fill_opacity` — дробное число от `0` до `1`, которое задаёт прозрачность заливки хороплета. Чем меньше число, тем более прозрачной будет фоновая картограмма.
# - `legend_name` — строка с подписью к цветовой легенде графика.
