# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
# Александр, привет!
#
# Меня зовут Сергей Кулешин, и я буду делать ревью твоего проекта. Давай будем общаться на «ты». Но если тебе комфортнее на «вы», обязательно сообщи мне об этом. Моя основная цель - не указать тебе на совершенные тобой ошибки, а поделиться своим опытом и помочь тебе стать аналитиком данных.
#
# Свои комментарии я буду выделять следующим образом:
# <div class="alert alert-danger">
#
#   <b>Комментарий ревьюера</b>
#
#   ❌ Так выделено то, что необходимо исправить, прежде чем я смогу принять твой проект.
# </div>
#
#
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Так отмечены не обязательные к доработке моменты. Mожешь учесть их при редактировании проекта. На твое усмотрение.
# </div>
#
#
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ А так удачные решения и подходы, на которые стоит опираться в будущих проектах.
# </div>
#
#
# <div style="border:solid black 2px; padding: 20px">
#
#
#   <b>Чек-лист доработок</b>
#
#   📃 Такой комментарий будет в конце тетрадки. В нем будут еще раз указаны нюансы, требующие обязательного исправления.
# </div>
#
# Предлагаю работать над проектом в форме диалога: если ты <b>что-то меняешь</b> в работе по моим рекомендациям — <b>напиши об этом</b> в ячейке `Markdown` и помечай комментарий каким-то заметным цветом, например так:
#
#
# ```
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Текст комментария.
# </div>
# ```
#
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Текст комментария.
# </div>
#
# Пожалуйста, <b>не перемещай, не изменяй и не удаляй мои комментарии</b>. Такой формат работы поможет выполнить повторную проверку твоего проекта оперативнее.
#
# <div style="background:#e5e5e5; color:#000; padding:10px">
#     <b>Общее впечатление о проекте</b>
#
# Проект выполнен без критических замечаний! Не принимаю сразу на случай, если у тебя есть какие-то вопросы.  Если вопросов нет - просто отправляй проект на проверку и я его сразу приму.
# </div>

# %% [markdown]
# # Поиск причины убытков в рекламе

# %% [markdown]
# Учебный проект по специальности "аналитик данных".
# Тема: анализ бизнес-показателей.
#
# Автор: Александр Лагутин.

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span><ul class="toc-item"><li><span><a href="#Заказчик" data-toc-modified-id="Заказчик-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Заказчик</a></span></li><li><span><a href="#Задача" data-toc-modified-id="Задача-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Задача</a></span></li><li><span><a href="#Входные-данные" data-toc-modified-id="Входные-данные-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Входные данные</a></span><ul class="toc-item"><li><span><a href="#Термины" data-toc-modified-id="Термины-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Термины</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Описание данных</a></span><ul class="toc-item"><li><span><a href="#Посещения-(visits)" data-toc-modified-id="Посещения-(visits)-1.3.2.1"><span class="toc-item-num">1.3.2.1&nbsp;&nbsp;</span>Посещения (visits)</a></span></li><li><span><a href="#Заказы-(orders)" data-toc-modified-id="Заказы-(orders)-1.3.2.2"><span class="toc-item-num">1.3.2.2&nbsp;&nbsp;</span>Заказы (orders)</a></span></li><li><span><a href="#Расходы-на-рекламу-(costs)" data-toc-modified-id="Расходы-на-рекламу-(costs)-1.3.2.3"><span class="toc-item-num">1.3.2.3&nbsp;&nbsp;</span>Расходы на рекламу (costs)</a></span></li></ul></li></ul></li><li><span><a href="#План-работы" data-toc-modified-id="План-работы-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>План работы</a></span></li><li><span><a href="#Инструменты" data-toc-modified-id="Инструменты-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Инструменты</a></span><ul class="toc-item"><li><span><a href="#Импорт-библиотек" data-toc-modified-id="Импорт-библиотек-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Импорт библиотек</a></span></li><li><span><a href="#Определения-констант" data-toc-modified-id="Определения-констант-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>Определения констант</a></span></li><li><span><a href="#Определения-функций" data-toc-modified-id="Определения-функций-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>Определения функций</a></span><ul class="toc-item"><li><span><a href="#Загрузка-и-обзор-данных" data-toc-modified-id="Загрузка-и-обзор-данных-1.5.3.1"><span class="toc-item-num">1.5.3.1&nbsp;&nbsp;</span>Загрузка и обзор данных</a></span></li><li><span><a href="#Исправление-данных" data-toc-modified-id="Исправление-данных-1.5.3.2"><span class="toc-item-num">1.5.3.2&nbsp;&nbsp;</span>Исправление данных</a></span></li><li><span><a href="#Преобразование-данных" data-toc-modified-id="Преобразование-данных-1.5.3.3"><span class="toc-item-num">1.5.3.3&nbsp;&nbsp;</span>Преобразование данных</a></span></li><li><span><a href="#Отображение-данных" data-toc-modified-id="Отображение-данных-1.5.3.4"><span class="toc-item-num">1.5.3.4&nbsp;&nbsp;</span>Отображение данных</a></span></li><li><span><a href="#Анализ-бизнеса" data-toc-modified-id="Анализ-бизнеса-1.5.3.5"><span class="toc-item-num">1.5.3.5&nbsp;&nbsp;</span>Анализ бизнеса</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Обзор-и-исправление-данных" data-toc-modified-id="Обзор-и-исправление-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Обзор и исправление данных</a></span><ul class="toc-item"><li><span><a href="#Посещения-visits" data-toc-modified-id="Посещения-visits-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Посещения <code>visits</code></a></span></li><li><span><a href="#Заказы-orders" data-toc-modified-id="Заказы-orders-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Заказы <code>orders</code></a></span></li><li><span><a href="#Расходы-на-рекламу-costs" data-toc-modified-id="Расходы-на-рекламу-costs-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Расходы на рекламу <code>costs</code></a></span></li><li><span><a href="#Итоги-обзора-и-исправления-данных" data-toc-modified-id="Итоги-обзора-и-исправления-данных-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Итоги обзора и исправления данных</a></span></li></ul></li><li><span><a href="#Анализ-обобщённых-данных" data-toc-modified-id="Анализ-обобщённых-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Анализ обобщённых данных</a></span><ul class="toc-item"><li><span><a href="#Профили-profiles" data-toc-modified-id="Профили-profiles-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Профили <code>profiles</code></a></span></li><li><span><a href="#Начало-привлечения-min_acq_date" data-toc-modified-id="Начало-привлечения-min_acq_date-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Начало привлечения <code>min_acq_date</code></a></span></li><li><span><a href="#Окончание-привлечения-max_acq_date" data-toc-modified-id="Окончание-привлечения-max_acq_date-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Окончание привлечения <code>max_acq_date</code></a></span></li><li><span><a href="#Пользователи-и-плательщики-по-странам,-устройствам-и-источникам" data-toc-modified-id="Пользователи-и-плательщики-по-странам,-устройствам-и-источникам-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Пользователи и плательщики по странам, устройствам и источникам</a></span></li><li><span><a href="#Итоги-оценки-обобщённых-данных" data-toc-modified-id="Итоги-оценки-обобщённых-данных-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Итоги оценки обобщённых данных</a></span></li></ul></li><li><span><a href="#Оценка-расходов-на-рекламу" data-toc-modified-id="Оценка-расходов-на-рекламу-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Оценка расходов на рекламу</a></span><ul class="toc-item"><li><span><a href="#Расходы-на-рекламу-(всего,-по-источникам-и-по-истории)" data-toc-modified-id="Расходы-на-рекламу-(всего,-по-источникам-и-по-истории)-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Расходы на рекламу (всего, по источникам и по истории)</a></span><ul class="toc-item"><li><span><a href="#Всего" data-toc-modified-id="Всего-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Всего</a></span></li><li><span><a href="#Распределение-расходов-по-источникам-пользователей" data-toc-modified-id="Распределение-расходов-по-источникам-пользователей-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Распределение расходов по источникам пользователей</a></span></li><li><span><a href="#История-расходов-на-рекламу" data-toc-modified-id="История-расходов-на-рекламу-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>История расходов на рекламу</a></span></li></ul></li><li><span><a href="#Cредний-CAC-на-пользователя-(всего,-и-по-источникам)" data-toc-modified-id="Cредний-CAC-на-пользователя-(всего,-и-по-источникам)-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Cредний CAC на пользователя (всего, и по источникам)</a></span></li><li><span><a href="#Итоги-оценки-расходов-на-рекламу" data-toc-modified-id="Итоги-оценки-расходов-на-рекламу-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Итоги оценки расходов на рекламу</a></span></li></ul></li><li><span><a href="#Оценка-окупаемости-пользователей" data-toc-modified-id="Оценка-окупаемости-пользователей-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Оценка окупаемости пользователей</a></span><ul class="toc-item"><li><span><a href="#Окупаемость-в-целом" data-toc-modified-id="Окупаемость-в-целом-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Окупаемость в целом</a></span></li><li><span><a href="#Окупаемость-по-каналам" data-toc-modified-id="Окупаемость-по-каналам-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Окупаемость по каналам</a></span><ul class="toc-item"><li><span><a href="#Обзор-ROI" data-toc-modified-id="Обзор-ROI-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Обзор ROI</a></span></li><li><span><a href="#Лучшая-окупаемость-каналов-в-недавнее-время" data-toc-modified-id="Лучшая-окупаемость-каналов-в-недавнее-время-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>Лучшая окупаемость каналов в недавнее время</a></span></li><li><span><a href="#Конверсия-по-источникам" data-toc-modified-id="Конверсия-по-источникам-5.2.3"><span class="toc-item-num">5.2.3&nbsp;&nbsp;</span>Конверсия по источникам</a></span></li><li><span><a href="#Удержание-по-источникам" data-toc-modified-id="Удержание-по-источникам-5.2.4"><span class="toc-item-num">5.2.4&nbsp;&nbsp;</span>Удержание по источникам</a></span></li><li><span><a href="#Рейтинг-источников" data-toc-modified-id="Рейтинг-источников-5.2.5"><span class="toc-item-num">5.2.5&nbsp;&nbsp;</span>Рейтинг источников</a></span></li><li><span><a href="#Выводы-по-каналам" data-toc-modified-id="Выводы-по-каналам-5.2.6"><span class="toc-item-num">5.2.6&nbsp;&nbsp;</span>Выводы по каналам</a></span></li></ul></li><li><span><a href="#Окупаемость-по-странам" data-toc-modified-id="Окупаемость-по-странам-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Окупаемость по странам</a></span><ul class="toc-item"><li><span><a href="#Выводы-по-странам" data-toc-modified-id="Выводы-по-странам-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>Выводы по странам</a></span></li></ul></li><li><span><a href="#Окупаемость-по-устройствам" data-toc-modified-id="Окупаемость-по-устройствам-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Окупаемость по устройствам</a></span><ul class="toc-item"><li><span><a href="#Выводы-по-устройствам" data-toc-modified-id="Выводы-по-устройствам-5.4.1"><span class="toc-item-num">5.4.1&nbsp;&nbsp;</span>Выводы по устройствам</a></span></li></ul></li><li><span><a href="#Метрики-внутри-TipTop-и-FaceBoom." data-toc-modified-id="Метрики-внутри-TipTop-и-FaceBoom.-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Метрики внутри TipTop и FaceBoom.</a></span><ul class="toc-item"><li><span><a href="#TipTop" data-toc-modified-id="TipTop-5.5.1"><span class="toc-item-num">5.5.1&nbsp;&nbsp;</span>TipTop</a></span></li><li><span><a href="#FaceBoom" data-toc-modified-id="FaceBoom-5.5.2"><span class="toc-item-num">5.5.2&nbsp;&nbsp;</span>FaceBoom</a></span></li><li><span><a href="#Выводы-по-проблемным-каналам" data-toc-modified-id="Выводы-по-проблемным-каналам-5.5.3"><span class="toc-item-num">5.5.3&nbsp;&nbsp;</span>Выводы по проблемным каналам</a></span></li></ul></li><li><span><a href="#Итоги-оценки-окупаемости-пользователей" data-toc-modified-id="Итоги-оценки-окупаемости-пользователей-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Итоги оценки окупаемости пользователей</a></span></li></ul></li><li><span><a href="#Общие-итоги" data-toc-modified-id="Общие-итоги-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общие итоги</a></span></li></ul></div>

# %% [markdown]
# ## Описание проекта
#
# ### Заказчик
#
# Команда развлекательного приложения Procrastinate Pro+.
#
# Основная деятельность: распространение ПО.
#
# ### Задача
#
# Компания много вкладывает в рекламу. Надо найти причину убытков, возникших в последние несколько месяцев.
#
# Для чего: чтобы рекламная компания окупала себя.

# %% [markdown]
# ### Входные данные
#
# Данные о пользователях, привлечённых с 1 мая по 27 октября 2019 года:
# - лог сервера с данными об их посещениях,
# - выгрузка их покупок за этот период,
# - расходы на рекламу.
#
# #### Термины
#
# Специальные термины не упомянуты.
#
# #### Описание данных
#
# ##### Посещения (visits)
#
# - `User Id` — идентификатор пользователя;
# - `Region` — страна;
# - `Device` — тип устройства;
# - `Channel` — источник;
# - `Session Start` — момент начала сессии;
# - `Session End` — момент конца сессии.
#
# ##### Заказы (orders)
#
# - `User Id` — идентификатор пользователя;
# - `Event Dt` - момент покупки;
# - `Revenue` - сумма покупки.
#
# ##### Расходы на рекламу (costs)
#
# - `Channel` - источник;
# - `Dt` - дата рекламы;
# - `Revenue` - сумма расходов.

# %% [markdown]
# ### План работы
#
# Найти ответы на вопросы:
# - откуда приходят пользователи;
# - какими устройствами они пользуются;
# - сколько стоит привлечение пользователей из разных рекламных каналов;
# - сколько денег приносит каждый клиент;
# - когда расходы на привлечение клиента окупаются;
# - что мешает привлечению клиентов.
#
# Действия:
# - [x] Импортировать библиотеки, описать функции, которые потребуются для расчёта и диаграмм LTV, ROI, RR и CR.
# - [x] Загрузить и изучить таблицы.
# - [x] Подготовить данные:
#   - [x] привести к норме названия столбцов;
#   - [x] привести данные к нужным типам;
#   - [x] обработать пропуски:
#     - [x] выбрать, чем заполнить (или оставить) и почему;
#     - [x] осуществить заполение, если требуется;
#     - [x] описать причины, которые могли привести к пропускам.
# - [x] Анализировать обобщённые данные:
#   - [x] Создать профили пользователей.
#     - [x] Найти минимальную и даты привлечения пользователей.
#   - [x] Построить таблицы "Количество пользователей" - "Доля плативших", сгруппированные по странам, устройствам и источникам.
#   - [x] Описать выводы.
# - [x] Оценить расходы на рекламу.
#   - [x] Сосчитать сумму расходов на маркетинг. Построить диаграммы, как расходы распределены по источникам и по истории.
#   - [x] Рассчитать средний CAC на пользователя:
#     - [x] Для всего проекта,
#     - [x] Для каждого источника.
#   - [x] Выводы
# - [x] Оценить окупаемость рекламы на 1.11.2019 на горизонте не позднее 2-х недель после привлечения.
#   - [x] Окупаемость рекламы в целом. Построить графики LTV и ROI, а также динамика LTV, CAC и ROI.
#   - [x] Окупаемость по странам, устройствам и каналам. Построить аналогичные графики.
#   - [x] Описать выводы.
#   - [x] Графики конверсии и удержания по устройствам, странам и источникам.
#     - [x] Окупается ли реклама?
#     - [x] Какие устройства, страны, каналы хуже всего показываают?
#     - [x] В чём причины?
#     - [x] Что рекомендуете рекламному отделу сделать?
# - [x] Описать общий вывод:
#   - [x] причины неэффективности;
#   - [x] рекомендации отделу маркетинга.

# %% [markdown]
# ### Инструменты
#
# Используем [Anaconda](https://www.anaconda.com/), окружение `ds_da_practicum_env.yml` "для Mac OS" (от 2022-03-23).

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Хорошо, что есть описание и цели проекта.
# </div>

# %% [markdown]
# #### Импорт библиотек

# %%
# %matplotlib inline

import datetime
import re

import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Определения констант

# %%
FIGSIZE = (10, 5)

# %% [markdown]
# #### Определения функций
#
# ##### Загрузка и обзор данных

# %%
def load(tablename, ext='csv'):
    """Load a table from file"""
    filename = tablename + '.' + ext
    try:
        df = pd.read_csv(filename)
    except FileNotFoundError:
        df = pd.read_csv('https://code.s3.yandex.net/datasets/' + filename)
    correct_column_names(df)  #  переводит в snake_case
    survey(df)  # даёт обзор возможных проблем с таблицей
    return df

# %%
def survey(data):
    """Display summaries to detect data problems"""
    display(data.sample(5))
    print(f'Полностью совпадающих строк: {data.duplicated().sum()}\n')
    data.info()
    display(get_nans(data))
    print(get_filled_rows_share(data))

# %%
def get_nans(data):
    nans = []
    for column in data.columns:
        missing = (
            data[column].isna().sum()
        )  # Подсчет количества отсутствующих значений
        part = round(
            missing * 100 / len(data), 2
        )  # Подсчет доли отсутствующих значений
        uniques = data[column].sort_values().nunique()
        nans.append([column, missing, part, uniques])

    return (
        pd.DataFrame(
            data=nans, columns=['column', 'na_count', 'na_%', 'unique_count']
        )
        .sort_values(['na_count', 'unique_count'], ascending=False)
        .set_index('column')
    )

# %%
def get_filled_rows_share(df):
    share = 1 - df.isna().any(axis=1).sum() / len(df)
    return f'Заполненных строк без пропусков: {share:.02%}'

# %% [markdown]
# ##### Исправление данных

# %%
def correct_column_names(df):
    df.columns = df.columns.str.strip()
    df.columns = df.columns.str.replace(' ', '_')
    df.columns = df.columns.map(to_snake_case)


def to_snake_case(name):
    name = re.sub('(.)([A-Z][a-z]+)', r'\1_\2', name)
    name = re.sub('__([A-Z])', r'_\1', name)
    name = re.sub('([a-z0-9])([A-Z])', r'\1_\2', name)
    return name.lower()

# %%
def fillnaby(data, column, groupby, func='median'):
    data[column] = data[column].fillna(
        data.groupby(groupby)[column].transform(func)
    )

# %% [markdown]
# ##### Преобразование данных
#
# ###### Moving Average: `add_ma`, `insert_ma`

# %%
def add_ma(df, window):
    """Return dataframe with added MA columns for each column"""
    for column in df.columns.values:
        df[column + '_ma_' + str(window)] = df[column].rolling(window).mean()
    return df

# %%
def insert_ma(df, window):
    """Return dataframe with inserted MA for each column"""
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean()
    return df

# %% [markdown]
# ##### Отображение данных

# %%
def headline(line, width=50):
    """Возвращает заголовок, набранный "простым текстом"."""
    return f'\n{line.upper():=^{width}}'

# %%
# можно было бы рисовать `bar` в случаях, когда вариантов мало.
# однако по неясной причине `bar` не рисуется, и не вызывает ошибки,
# а вызывает лишь зацикливание при построении первого же графика


def survey_columns(df):
    for column in nans_before.index:
        print(headline(column))

        uniques = realty[column].sort_values().unique()
        if len(uniques) < 20:
            print(uniques)
        print(f'Data type: {str(realty[column].dtype):>10}')
        print(f'Unique values: {len(uniques):6}')

        missing = realty[column].isna().sum()
        if missing:
            print(f'Not avaliable: {nans_before.loc[column, "na_part"]:.02%}')
        else:
            print('All values is avaliable.')

        try:
            realty.plot(
                kind='hist',
                y=column,
                bins=50,
            )
            plt.show()
        except Exception as e:
            print(str(e).capitalize())

# %%
# формирует и выводит график, подстроенный под наши нужды
def histf(
    data,
    column,
    show=True,
    bins=100,
    qtl=1,
    start=None,
    stop=None,
    figsize=FIGSIZE,
    **kwargs,
):
    fixed = {
        'y': column,
        'kind': 'hist',
        'bins': min(bins, len(data[column].unique())),
        'figsize': figsize,
        'title': column,
        'legend': False,
        'ec': 'black',
    }
    if 'range' not in kwargs.keys():
        if not start:
            start = data[column].min()
        if not stop:
            stop = data[column].quantile(qtl)
        kwargs['range'] = (start, stop)
    data.plot(**fixed, **kwargs)
    if show:
        plt.show()


def histf2(data, column1, column2, **kwargs):
    histf(column1, data=data, show=False, **kwargs)
    histf(column2, data=data, show=False, **kwargs)
    plt.show()


# два графика: все случаи, и те, что менее указанного квантиля
def dhistf(column, data, qtl=0.975, figsize=FIGSIZE, **kwargs):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=figsize)
    fig.suptitle('This is a somewhat long figure title', fontsize=16)

    ax1.set_title('full_data')
    ax2.set_title(f'{qtl:.2%} quantile')
    histf(column, data=data, ax=ax1, subplots=True, show=False, **kwargs)
    histf(
        column, data=data, ax=ax2, subplots=True, show=False, qtl=qtl, **kwargs
    )
    plt.show()


# Развитая форма этого чудовища должна принимать список квантилей,
# и строить столько графиков, сколько квантилей указано,
# и качестве центра диапазона выбирать медиану.
# Пора перейти к аналитике.

# %%
def typical(data, column, ratio=1.5):
    q1 = data[column].quantile(0.25)
    q3 = data[column].quantile(0.75)
    iqr = q3 - q1
    whiskers = iqr * ratio
    low = q1 - whiskers
    high = q3 + whiskers

    print(
        f'{column.title()}: min = {data[column].min()},'
        f' max = {data[column].max()},'
        f' normal range = [{low:.2f} ... {high:.2f}]'
    )

    return data.query(f'@low <= {column} <= @high')

# %%
quantitative_properties = []

categorical_properties = []

key_column = ''


def batch_corr(data, column=key_column):
    print(headline('Коэффициенты линейной корреляции'))
    display(
        data.reindex(
            columns=(quantitative_properties + categorical_properties)
        )
        .corr()[column]
        .sort_values(ascending=False)
    )


def batch_scatter(data, column=key_column):
    for prop in quantitative_properties:
        if prop == column:
            continue
        data.plot(
            kind='scatter',
            alpha=0.2,
            figsize=FIGSIZE,
            y=column,
            x=prop,
        )
    plt.show()


def batch_box(data, column=key_column, by_props=categorical_properties):
    for prop in by_props:
        data.boxplot(
            column=column,
            by=prop,
            figsize=FIGSIZE,
        )
    plt.show()

# %% [markdown]
# ##### Анализ бизнеса

# %% [markdown]
# ###### Профили: `get_profiles`

# %%
def get_profiles(sessions, orders, ad_costs):
    """Return user action profiles"""

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# ###### Конверсия `get_conversion`, `plot_conversion`

# %%
def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):
    """Return conversion rates"""

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - datetime.timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis=1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
def plot_conversion(conversion, conversion_history, horizon, window=7):
    """Plot conversion and CR history"""

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 7))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name
        for name in conversion_history.index.names
        if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    insert_ma(filtered_data, window).plot(grid=True, ax=ax2, legend=None)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика конверсии пользователей после {}-го дня'.format(horizon)
    )

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ###### Удержание: `get_retention`, `plot_retention`

# %%
def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):
    """Return retention rates"""

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - datetime.timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
def plot_retention(retention, retention_history, horizon, window=7):
    """Plot retention and RR history"""

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1, legend=None
    )
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = (
        retention_history.query('payer == True')
        .pivot_table(
            index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
        )
        .fillna(0)
    )
    insert_ma(filtered_data, window).plot(grid=True, ax=ax3, legend=None)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей после {}-го дня'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    insert_ma(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей после {}-го дня'.format(
            horizon
        )
    )

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ###### Окупаемость `get_ltv`, `plot_ltv`

# %%
def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):
    """Return lifetime value and return of investments"""

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - datetime.timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    def group_by_dimensions(df, dims, horizon_days):

        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC,
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %%
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):
    """Plot lifetime value of user, return of investments and its history"""

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(15, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    insert_ma(filtered_data, window).plot(grid=True, ax=ax2, legend=None)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей после {}-го дня'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    insert_ma(filtered_data, window).plot(grid=True, ax=ax3, legend=None)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    insert_ma(filtered_data, window).plot(grid=True, ax=ax5, legend=None)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей после {}-го дня'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Отличные функции!
# </div>

# %% [markdown]
# ## Обзор и исправление данных

# %% [markdown]
# ### Посещения `visits`

# %%
visits = load('visits_info_short')
# Out:
#              user_id         region   device       channel  \
# 78321   913385823084  United States   iPhone        TipTop
# 201795  285705212780  United States   iPhone  MediaTornado
# 170823  439735851429  United States  Android        TipTop
# 64661   268918173719  United States   iPhone       organic
# 78024   813200494892  United States      Mac  MediaTornado
#
#               session_start          session_end
# 78321   2019-07-17 12:56:37  2019-07-17 13:03:49
# 201795  2019-10-26 21:30:19  2019-10-26 21:43:51
# 170823  2019-10-03 22:52:23  2019-10-03 23:15:30
# 64661   2019-07-04 13:35:36  2019-07-04 13:38:57
# 78024   2019-07-17 05:47:30  2019-07-17 06:22:57
# Полностью совпадающих строк: 0
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
# ...

# %% [markdown]
# Данные полны. Посещения идут из 11 источников. 4 региона и 4 типа устройств. Приводим даты и время к нужным типам.

# %%
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_start'])

visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  datetime64[ns]
#  5   session_end    309901 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 14.2+ MB

# %% [markdown]
# ### Заказы `orders`

# %%
orders = load('orders_info_short')
# Out:
#             user_id             event_dt  revenue
# 18513  714000466105  2019-09-17 22:29:27     4.99
# 22930  994569702980  2019-10-08 01:41:35     4.99
# 5919   602694963692  2019-07-02 14:43:30     4.99
# 20405  267033190867  2019-09-27 06:47:51     4.99
# 38205  571776790240  2019-10-12 03:06:35     4.99
# Полностью совпадающих строк: 0
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  object
#  2   revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB
#           na_count  na_%  unique_count
# column
# event_dt         0   0.0         40163
# user_id          0   0.0          8881
# revenue          0   0.0             5
# Заполненных строк без пропусков: 100.00%

# %% [markdown]
# Данные по заказам также полны. Моменты входа приводим к нужному типу.

# %%
orders['event_dt'] = pd.to_datetime(orders['event_dt'])

orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  datetime64[ns]
#  2   revenue   40212 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 942.6 KB

# %% [markdown]
# ### Расходы на рекламу `costs`

# %%
costs = load('costs_info_short')
# Out:
#               dt       channel   costs
# 212   2019-06-02  MediaTornado    3.60
# 903   2019-05-04    AdNonSense   51.45
# 649   2019-08-18        TipTop  450.00
# 1016  2019-08-25    AdNonSense   18.90
# 569   2019-05-30        TipTop  153.90
# Полностью совпадающих строк: 0
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB
#          na_count  na_%  unique_count
# column
# costs           0   0.0           608
# dt              0   0.0           180
# channel         0   0.0            10
# Заполненных строк без пропусков: 100.00%

# %% [markdown]
# Пропусков и повторов нет. Данные за 180 дней. Даты приводим к нужному типу.

# %%
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %% [markdown]
# ### Итоги обзора и исправления данных
#
# - Названия колонок приведены к норме автоматически.
# - Нет пропусков и дубликатов.
# - Дати и время приведены к соответсвующему типу.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Данные получены и подготовлены к анализу! Хорошо, что заметил неверный формат даты и поменял.
# </div>

# %% [markdown]
# ## Анализ обобщённых данных

# %% [markdown]
# Прямо не указано, и по данным не ясно, когда началось привлечение клиентов. Это следовало бы запросить у заказчика.
#
# Предполагаем, что эти данные включают в себя историю привлечения с самого начала. Считаем, что сервиса не было посещений ранее, чем те, которые описаны в таблице посещений. Считаем, что не было расходов на привлечение ранее, чем указано в таблице расходов.
#
# Также не описаны подробности: какую платформу использует приложение для работы, размещено ли на ресурсе что-то помимо приложения, какие действия мы ожидаем от пользователей и какие они фактически совершают.
#
# Предполагаем, что ресурс представлен одной страницей (единой для всех пользователей), на которой лишь один целевой шаг - "заказать", и объект, который может привлечь пользователей (товар), тоже только один - "доступ к приложению".

# %% [markdown]
# ### Профили `profiles`

# %%
profiles = get_profiles(visits, orders, costs)
profiles.head()
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %%
profiles['user_id'].count()
# Out:
# 150008

# %%
visits['user_id'].nunique()
# Out:
# 150008

# %% [markdown]
# Итого, за всё время статистики привлечено 150 008 пользователей.

# %%
profiles['payer'].mean() * 100
# Out:
# 5.920350914617887

# %% [markdown]
# Из них 5,92% - делали заказы.

# %% [markdown]
# ### Начало привлечения `min_acq_date`

# %%
min_ack_date = profiles['dt'].min()
print(
    'Самая раннняя известная дата привлечения:',
    min_ack_date.strftime('%Y-%m-%d'),
)
# Out:
# Самая раннняя известная дата привлечения: 2019-05-01

# %% [markdown]
# ### Окончание привлечения `max_acq_date`

# %%
max_ack_date = profiles['dt'].max()
print(
    'Самая поздняя известная дата привлечения:',
    max_ack_date.strftime('%Y-%m-%d'),
)
# Out:
# Самая поздняя известная дата привлечения: 2019-10-27

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Замечательно, у нас есть даты и они совпадают с заданием!
# </div>
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Стоит подписывать выводимые значения.
# </div>
#
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Подписал значения.
# </div>
# <div class="alert alert-success">
#
# <b>Комментарий ревьюера v.2</b>
#
#   ✔️ 👌
# </div>

# %% [markdown]
# ### Пользователи и плательщики по странам, устройствам и источникам

# %%
dimensions = ['channel', 'region', 'device']

for dim in dimensions:
    print(headline('by ' + dim))
    pivots = (
        profiles.groupby(dim)
        .agg({'user_id': 'nunique', 'payer': 'mean'})
        .rename(columns={'user_id': 'total_users', 'payer': 'payer_part'})
        .sort_values('payer_part', ascending=False)
    )
    display(pivots)
    pivots['payer_part'].plot(kind='bar')
    plt.ylabel('Доля платящих')
    plt.show()
# Out:
# ====================BY CHANNEL====================
#                     total_users  payer_part
# channel
# FaceBoom                  29144    0.122049
# AdNonSense                 3880    0.113402
# lambdaMediaAds             2149    0.104700
# TipTop                    19561    0.096007
# RocketSuperAds             4448    0.079137
# WahooNetBanner             8553    0.052964
# YRabbit                    4312    0.038265
# MediaTornado               4364    0.035747
# LeapBob                    8553    0.030633
# OppleCreativeMedia         8605    0.027077
# organic                   56439    0.020553
# ====================BY REGION=====================
#                total_users  payer_part
# region
# United States       100002    0.069019
# Germany              14981    0.041119
# UK                   17575    0.039829
# France               17450    0.037994
# ====================BY DEVICE=====================
#          total_users  payer_part
# device
# ...

# %% [markdown]
# ### Итоги оценки обобщённых данных
#
# - В данных описано привлечение пользователей с 1 мая по 27 октября 2019 года включительно.
#
# - Самый качественный канал - FaceBoom: он привлёк больше, чем любой другой именованный канал, и доля плательщиков среди этих пользователей - наивысшая.
#
# - Большая часть пользователей приходит из США. Доля плательщиков также выше среди пользователей из США. Остальные страны привлекают лишь треть пользователей, доля плательщиков среди них ниже, чем среди американцев.
#
# - Среди пользователей разных устройств различия невелики. Доля плательщиков среди пользователей PC ниже, чем у других пользователей. Количество пользователей iPhone существенно выше, чем пользователей других платформ.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ С платящими определились!
# </div>

# %% [markdown]
# ## Оценка расходов на рекламу

# %% [markdown]
# ### Расходы на рекламу (всего, по источникам и по истории)

# %% [markdown]
# #### Всего

# %%
total_costs = costs['costs'].sum()
total_costs
# Out:
# 105497.30000000002

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Общие затраты посчитали.
# </div>

# %% [markdown]
# #### Распределение расходов по источникам пользователей

# %%
channel_costs = (
    costs.groupby('channel')
    .agg({'costs': 'sum'})
    .sort_values('costs', ascending=False)
)
channel_costs['%'] = channel_costs['costs'] / total_costs * 100

display(channel_costs)

channel_costs['costs'].plot.bar(figsize=FIGSIZE, ylabel='total_costs', rot=45)
plt.show()
# Out:
#                        costs          %
# channel
# TipTop              54751.30  51.898295
# FaceBoom            32445.60  30.754910
# WahooNetBanner       5151.00   4.882589
# AdNonSense           3911.25   3.707441
# OppleCreativeMedia   2151.25   2.039152
# RocketSuperAds       1833.00   1.737485
# LeapBob              1797.60   1.703930
# lambdaMediaAds       1557.60   1.476436
# MediaTornado          954.48   0.904744
# YRabbit               944.22   0.895018

# %% [markdown]
# Видим, что основные расходы идут на TipTop и FaceBoom. Остальные источники получили мало вложений.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️  На популярные каналы тратится больше. Здорово, что рассчитан процент затрат каждого канала от общей суммы! Видим, что два канала съели более 80% бюджета.
#
# </div>

# %% [markdown]
# #### История расходов на рекламу

# %%
add_ma(
    profiles.groupby('dt').agg({'user_id': 'nunique'}).sort_values('dt'),
    7,
).plot(
    figsize=FIGSIZE,
    grid=True,
    xlabel='Дата привлечения',
    ylabel='Новых пользователей в день',
    title='История привлечения пользователей',
)
plt.show()

# %% [markdown]
# К моменту исследования к проекту ежедневно присоединяется столько же пользователей, сколько и в начале проекта, в мае. Больше новых пользователей бывает в концах месяцев, а в серединах месяцев - меньше.

# %%
date_costs = costs.groupby('dt').agg({'costs': 'sum'})

add_ma(date_costs, 7).plot(
    figsize=FIGSIZE,
    grid=True,
    xlabel='Дата привлечения',
    ylabel='Расходы',
    title='Расходы на привлечение',
)
plt.show()

# %% [markdown]
# Расходы непрерывно растут. У них та же периодичность, что и у потока новых пользователей.

# %%
insert_ma(
    costs.pivot_table(
        index='dt', columns='channel', values='costs', aggfunc='sum'
    ),
    7,
).plot(
    figsize=FIGSIZE,
    grid=True,
    xlabel='Дата привлечения',
    ylabel='Расходы',
    title='Расходы на привлечение по источникам',
)
plt.show()

# %% [markdown]
# Расходы на каждый из источников повторяют ту периодичность, которую мы заметили. Нет заметных всплесков, отклонений. В целом расходы на TipTop заметно растут (каждый следующий пик сильно выше предыдущего). Также много уходит на FaceBoom. Остальные источники мало заметны на фоне этих двух.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Видим динамику расходов.
# </div>

# %% [markdown]
# ### Cредний CAC на пользователя (всего, и по источникам)

# %%
paid_profiles = profiles.query('channel != "organic"')

costs['costs'].sum() / paid_profiles['user_id'].nunique()
# Out:
# 1.127481323942759

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Правильно, что убираем из расчетов  пользователей с органическим трафиком, ведь мы за них ничего не платим.
# </div>

# %% [markdown]
# Средняя цена привлечения оплаченного (не "органического") пользователя - 1.13 . Эта цена рассчитана из предположения, что все пользователи не посещали ресурс проекта до 1 мая.

# %%
channel_users = (
    visits.sort_values('session_start')
    .groupby('user_id')
    .agg({'user_id': 'first', 'channel': 'first'})
    .groupby('channel')
    .agg({'user_id': 'nunique'})
    .rename(columns={'user_id': 'unique_users'})
)

channels = channel_costs.join(channel_users, how='outer').fillna(0)
channels['cac'] = channels['costs'] / channels['unique_users']
channels.sort_values('cac')
# Out:
#                        costs          %  unique_users       cac
# channel
# organic                 0.00   0.000000         56439  0.000000
# LeapBob              1797.60   1.703930          8553  0.210172
# MediaTornado          954.48   0.904744          4364  0.218717
# YRabbit               944.22   0.895018          4312  0.218975
# OppleCreativeMedia   2151.25   2.039152          8605  0.250000
# RocketSuperAds       1833.00   1.737485          4448  0.412095
# WahooNetBanner       5151.00   4.882589          8553  0.602245
# lambdaMediaAds       1557.60   1.476436          2149  0.724802
# AdNonSense           3911.25   3.707441          3880  1.008054
# FaceBoom            32445.60  30.754910         29144  1.113286
# TipTop              54751.30  51.898295         19561  2.799003

# %%
# проверим, что общее количество пользователей не изменилось после преобразования
channels['unique_users'].sum()
# Out:
# 150008

# %% [markdown]
# Органические пользователи составляют треть из всех привлечённых пользователей.
#
# Каналы "LeapBob", "MediaTornado", "YRabbit", "OppleCreativeMedia" имеют самые низкие расходы на привлечение одного пользователя. Два основных платных источника являются также двумя самыми дорогими, в пересчёте на одного пользователя.

# %% [markdown]
# ### Итоги оценки расходов на рекламу
#
# - TipTop - самый дорогой источник пользователей, на него пришлась половина расходов, и именно он получал дополнительные средства, которыми увеличивался рекламный бюджет;
# - FaceBoom - следующий по дороговизне и по величине расходов канал;
# - Каналы с меньшими CAC финансируются мало.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ И обходятся популярные каналы дороже.
#
# </div>

# %% [markdown]
# ## Оценка окупаемости пользователей

# %% [markdown]
# ### Окупаемость в целом
#
# Оценим, как окупается реклама к 1 ноября 2019 года.
#
# В бизнес-плане заложено, что "пользователи должны окупаться не позднее чем через две недели после привлечения". Горизонтом анализа становятся 14 суток.
#
# Для анализа окупаемости исключим "органических" пользователей. Их много, на их привлечение не было расходов, и они необоснованно улучшат статистику окупаемости, если их включить в один отчёт с платными источниками.

# %%
observation_date = datetime.date(2019, 11, 1)
horizon = 14

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(
    paid_profiles,
    orders,
    observation_date,
    horizon,
)

plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7)

# %% [markdown]
# Срений доход от пользователя остаётся на одном уровне.
#
# Средняя стоимость привлечения пользователя растёт.
#
# Это приводит к тому, что расходы на рекламу со временем перестают окупаться. В данном случае ROI около 1 установилися в конце мая, а с середины июня реклама не окупает себя.
#
# ### Окупаемость по каналам
#
# #### Обзор ROI
#
# Графики проведём не по данным за день, и не по среднему за 7 дней, а по среднему за банковский месяц - 30 дней. Этим мы сглаживаем колебания, происходящие внутри месяца (например, регулярные подъёмы цены на границах месяца, падения в серединах).

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Да, наблюдаем явные проблемы.
# </div>

# %%
window = 30


def show(dimensions, window=window, profiles=paid_profiles):
    ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(
        profiles,
        orders,
        observation_date,
        horizon,
        dimensions=dimensions,
    )
    plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window)

# %%
show(['channel'])

# %% [markdown]
# **Плохие новости**:
#
# В среднем за всю историю не окупают себя три канала: TipTop, FaceBoom и AdNonSense.
#
# По динамике стоимости привлечения видим: TipTop постоянно дорожает. На момент анализа цена выше в 3-10 раз по сравнению с другими источниками.
#
# LTV у FaceBoom, AdNonSense, и некоторых других источников - очень пологий. Это показывает, что пользователи, пришедшие из этих источников, делают мало покупок в последующие дни, после привлечения. Говоря профессионально, следует проверить коэффициенты удержания по источникам.
#
# **Хорошие новости**:
#
# YRabbit летом был наиболее окупаемым, за счёт того что снижалась цена, и повышалась отдача с пользователя. На момент анализа это цена вновь повышается, а LTV падает, однако канал всё ещё среди лучших по ROI на момент анализа.
#
# RocketSuperAds становится дешевле.
#
# Есть много каналов, которые показывают хороший ROI. Составим рейтинг, чтобы понять, какие из них самые привлекательные.

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Стоит перечислить все не окупающиеся каналы, их у нас всего 3.
# </div>
#
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Добавил описание проблем третьего убыточного канала.
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ Определили проблемные каналы!
# </div>

# %% [markdown]
# #### Лучшая окупаемость каналов в недавнее время

# %%
# выбираем пользователей, привлечённых в последние 30 дат из тех,
# которые успели "дожить" до горизонта анализа
end = observation_date - datetime.timedelta(days=(horizon - 1))
start = end - datetime.timedelta(days=(window - 1))
actual_paid_profiles = paid_profiles.query('@start <= dt <= @end').sort_values(
    'first_ts'
)

# получаем ROI выборки - по каналам
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(
    actual_paid_profiles,
    orders,
    observation_date,
    horizon,
    dimensions=['channel'],
)

# создаём рейтинг по выборке
# больше когорта - лучше
# больше ROI - лучше
rating = (
    roi[['cohort_size', 13, 0, 'cac']]
    .rename(columns={13: 'roi_13', 0: 'roi_0'})
    .sort_values('roi_13', ascending=False)
)

# больше LTV - лучше
rating = rating.join(ltv[[13, 0]].rename(columns={13: 'ltv_13', 0: 'ltv_0'}))

# покажем числа рейтинга
display(rating)

# покажем разницу в ROI истчников наглядно
actual_dates = f'c {start.strftime("%d.%m.%Y")} по {end.strftime("%d.%m.%Y")}'
rating['roi_13'].plot.bar(
    ylabel='ROI', title=f'Актуальная окупаемость источников {actual_dates}'
)
plt.show()
# Out:
#                     cohort_size    roi_13     roi_0       cac    ltv_13  \
# channel
# MediaTornado                798  2.888554  0.844697  0.211729  0.611591
# lambdaMediaAds              375  2.740919  0.752169  0.725333  1.988080
# YRabbit                     825  2.665680  0.958004  0.221091  0.589358
# RocketSuperAds              823  2.583394  0.548352  0.298542  0.771252
# LeapBob                    1793  2.426510  0.448364  0.211054  0.512125
# OppleCreativeMedia         1865  2.038179  0.483235  0.250268  0.510091
# WahooNetBanner             1847  1.367059  0.241310  0.606822  0.829561
# AdNonSense                  658  1.002699  0.566414  0.990957  0.993632
# FaceBoom                   6138  0.751082  0.544331  1.115233  0.837631
# TipTop                     4149  0.403510  0.096819  3.545553  1.430668
#
#                        ltv_0
# channel
# MediaTornado        0.178847
# lambdaMediaAds      0.545573
# YRabbit             0.211806
# RocketSuperAds      0.163706
# ...

# %% [markdown]
# У нас появилась таблица рейтинга, которую будем пополнять. По окупаемости интерес представляют первые четыре-шесть источников.
#
# Два крупнейших источника - являются худшими по окупаемости. Посмотрим причину. Для удобства сперва проверим конверсию из посетителей в плательщики. Нам предстоит определить не только худшие когорты, но и лучшие - те, которые порекоменуем увеличить.

# %% [markdown]
# #### Конверсия по источникам

# %%
conversion_raw, conversion, conversion_history = get_conversion(
    profiles,
    orders,
    observation_date,
    horizon,
    dimensions=['channel'],
)

plot_conversion(conversion, conversion_history, horizon, window=window)

# %% [markdown]
# FaceBoom - лучший по конверсии среди каналов. TipTop тоже относительно высоко.

# %% [markdown]
# Добавим в рейтинг актуальную среднюю конверсию.

# %%
_, conversion, _ = get_conversion(
    actual_paid_profiles,
    orders,
    observation_date,
    horizon,
    dimensions=['channel'],
)

rating_conv = rating.join(conversion[[13, 0]]).rename(
    columns={13: 'conversion_13', 0: 'conversion_0'}
)
rating_conv.sort_values('conversion_13', ascending=False)
# Out:
#                     cohort_size    roi_13     roi_0       cac    ltv_13  \
# channel
# AdNonSense                  658  1.002699  0.566414  0.990957  0.993632
# lambdaMediaAds              375  2.740919  0.752169  0.725333  1.988080
# FaceBoom                   6138  0.751082  0.544331  1.115233  0.837631
# TipTop                     4149  0.403510  0.096819  3.545553  1.430668
# RocketSuperAds              823  2.583394  0.548352  0.298542  0.771252
# WahooNetBanner             1847  1.367059  0.241310  0.606822  0.829561
# MediaTornado                798  2.888554  0.844697  0.211729  0.611591
# YRabbit                     825  2.665680  0.958004  0.221091  0.589358
# LeapBob                    1793  2.426510  0.448364  0.211054  0.512125
# OppleCreativeMedia         1865  2.038179  0.483235  0.250268  0.510091
#
#                        ltv_0  conversion_13  conversion_0
# channel
# AdNonSense          0.561292       0.127660      0.095745
# ...

# %%
fig, ax = plt.subplots()
ax.scatter(
    rating_conv['conversion_0'],
    rating_conv['ltv_0'],
    c='blue',
    label='В первый день',
)
ax.scatter(
    rating_conv['conversion_13'],
    rating_conv['ltv_13'],
    c='green',
    label='Через 2 недели',
)
ax.legend()
ax.grid(True)
plt.xlabel('Конверсия')
plt.ylabel('LTV')
plt.show()

# %% [markdown]
# Есть прямая взаимосвязь между конверсией и LTV. Так и должно быть. Однако через 2 недели два источника с наилучшей конверсией имеют недостаточно высокий LTV. Это AdNonSense и FaceBoom.
#
# Возможная причина - уже "конвертировавшиеся" (сделавшие покупку один раз) делают относительно мало повторных покупок (плохое "удержание" плательщиков).

# %% [markdown]
# #### Удержание по источникам

# %%
retention_raw, retention, retention_history = get_retention(
    paid_profiles,
    visits,
    observation_date,
    horizon,
    dimensions=['channel'],
)

# %%
plot_retention(retention, retention_history, horizon, window=window)

# %% [markdown]
# В большинстве каналов - мало платящих пользователей. Поэтому динамика у них сильно колеблется - каждый пользователь ощутимо меняет статистику.
#
# Однако два самых крупных канала - стабильны. В них пользователей много.
#
# FaceBoom показывает худшее удержание.
#
# TipTop - одно из лучших.
#
# Добавим в таблицу рейтинга столбец с удержанием пользователей за последний месяц.

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Не уверен насчет 3 месяцев, лучше пусть будут пропуски на графиках.
# </div>
#
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Пропусков не получится, поскольку там где функция не получает аргумент "количество пользователей" - она устанавливает, что пользователей 0.
#
#   Я установил "окно" усреднения на 30 дней, как везде.
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ Так лучше, не теряем на графиках начало анализа.
# </div>

# %%
actual_paid_payer_profiles = actual_paid_profiles.query('payer == True')
_, retention, _ = get_retention(
    actual_paid_payer_profiles,
    visits,
    observation_date,
    horizon,
    dimensions=['channel'],
)

rating_ret = (
    rating_conv.join(retention[13])
    .rename(columns={13: 'payer_retention_13'})
    .droplevel('payer')
)
rating_ret.sort_values('payer_retention_13', ascending=False)
# Out:
#                     cohort_size    roi_13     roi_0       cac    ltv_13  \
# channel
# lambdaMediaAds              375  2.740919  0.752169  0.725333  1.988080
# OppleCreativeMedia         1865  2.038179  0.483235  0.250268  0.510091
# LeapBob                    1793  2.426510  0.448364  0.211054  0.512125
# WahooNetBanner             1847  1.367059  0.241310  0.606822  0.829561
# RocketSuperAds              823  2.583394  0.548352  0.298542  0.771252
# TipTop                     4149  0.403510  0.096819  3.545553  1.430668
# MediaTornado                798  2.888554  0.844697  0.211729  0.611591
# YRabbit                     825  2.665680  0.958004  0.221091  0.589358
# AdNonSense                  658  1.002699  0.566414  0.990957  0.993632
# FaceBoom                   6138  0.751082  0.544331  1.115233  0.837631
#
#                        ltv_0  conversion_13  conversion_0  payer_retention_13
# channel
# lambdaMediaAds      0.545573       0.122667      0.088000            0.260870
# ...

# %% [markdown]
# Худшее удержание платящих - у FaceBoom, AdNonSense и YRabbit. Приемлемым можно считать удержание четырёх лучших источников.
#
# #### Рейтинг источников

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Видим причину не окупаемости каналов FaceBoom и AdNonSense.
# </div>

# %% [markdown]
# Добавим информацию о расходах за тот промежуток времени, по которому строится рейтинг.

# %%
actual_costs = (
    costs.query('@start <= dt <= @end')
    .groupby('channel')
    .agg({'costs': 'sum'})
)

rating_final = (
    rating_ret.drop(columns=['roi_0', 'ltv_0', 'conversion_0'])
    .sort_values('roi_13', ascending=False)
    .join(actual_costs)
    .reindex(
        columns=[
            'cohort_size',
            'costs',
            'cac',
            'conversion_13',
            'payer_retention_13',
            'ltv_13',
            'roi_13',
        ]
    )
)

rating_final
# Out:
#                     cohort_size     costs       cac  conversion_13  \
# channel
# MediaTornado                798    168.96  0.211729       0.038847
# lambdaMediaAds              375    272.00  0.725333       0.122667
# YRabbit                     825    182.40  0.221091       0.036364
# RocketSuperAds              823    245.70  0.298542       0.068044
# LeapBob                    1793    378.42  0.211054       0.029002
# OppleCreativeMedia         1865    466.75  0.250268       0.027882
# WahooNetBanner             1847   1120.80  0.606822       0.049269
# AdNonSense                  658    652.05  0.990957       0.127660
# FaceBoom                   6138   6845.30  1.115233       0.122515
# TipTop                     4149  14710.50  3.545553       0.090383
#
#                     payer_retention_13    ltv_13    roi_13
# channel
# MediaTornado                  0.090909  0.611591  2.888554
# lambdaMediaAds                0.260870  1.988080  2.740919
# ...

# %% [markdown]
# (Тут была бы удобна визуалиация "хитмэп, в котором диапазон не общий на всю таблицу, а индивидуальный у каждой колонки".)

# %% [markdown]
# #### Выводы по каналам
#
# - На момент исследования большинство средств уходят в два наименее эффективных канала.
#
# **Рекомендации**:
#
# - TipTop нужно закупать дешевле в много раз (снизать CAC),
# - FaceBoom - поднять удержание.
#   - Узнать причины, по которым пользователи так редко повторяют заказы. Пользователи  ожидают что-то, а их ожидания не оправдываются, и они уходят? Пусть сревис предоставит это, и конверсия улучшится.
# - Больше расходов на каналы с высоким ROI:
#   - На каналы с низкой ценой за пользователя (MediaTornado, YRabbit, RocketSuperAds, LeapBob)
#     - Это приведёт к большей аудитории, узнаваемости, нагрузкам и расходам на поддержку аудитории.
#   - На каналы с высоким LTV (lambdaMediaAds)
#     - Это ведёт к активной лояльной аудитории, но небольшой, и, возможно, не склонной платить больше, или за другие (смежные) проекты.

# %% [markdown]
# ### Окупаемость по странам

# %%
show(['region'])

# %% [markdown]
# В конце августа - середине сентября доход с британских пользователей резко упал. То же самое случилось с французскими в октябре.
#
# Доход от пользователей из США выше, но расходы - ещё выше, и постоянно растут. В результате окупаемость по этому региону упала далеко ниже 1.
#
# Мы видели подобное в канале "TipTop". Попробуем выяснить, сколько есть пользователей из США, пришедших через TipTop.

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Согласен, можно еще изучить рекламу в США и Европе отдельно.
# </div>
#
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Это как? Разделить пользователей на две группы "Европа" и "Америка", и отобразить метрики каждой по отдельности?
#
#   Я предпочёл не объединять страны. Их всего 4, не запутаемся. Если они однотипны - мы увидим это на графиках. Если они разные - то не стоит объединять их в группу.
# </div>
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ⚠️ У нас основная масса покупателей из США, так что можно создать отдельный датафрейм, например `profiles_usa`, и выбрать в него только пользователей по США: `profiles_usa = profiles.query('region == "United States"')`  дальше по этому датафрейму построить графики из текущего шага с разбивкой по каналам и устройствам. Европу можно аналогично рассмотреть, но не разбивать на страны, там показатели примерно одинаковые и клиентов мало `('region != "United States"')`
# </div>

# %%
profiles_by_channel_region = paid_profiles.pivot_table(
    index='channel',
    columns='region',
    values='user_id',
    aggfunc='nunique',
).fillna(0)
profiles_by_channel_region
# Out:
# region              France  Germany      UK  United States
# channel
# AdNonSense          1366.0   1219.0  1295.0            0.0
# FaceBoom               0.0      0.0     0.0        29144.0
# LeapBob             2988.0   2519.0  3046.0            0.0
# MediaTornado           0.0      0.0     0.0         4364.0
# OppleCreativeMedia  2991.0   2562.0  3052.0            0.0
# RocketSuperAds         0.0      0.0     0.0         4448.0
# TipTop                 0.0      0.0     0.0        19561.0
# WahooNetBanner      2971.0   2579.0  3003.0            0.0
# YRabbit                0.0      0.0     0.0         4312.0
# lambdaMediaAds       742.0    649.0   758.0            0.0

# %% [markdown]
# Каналы чётко делятся на европейские и американские. Сверхдорожавший TipTop и FaceBoom, пришедшие по котором пользователи теряются - это американские источники. Распределим профили по категориям, и оценим только ту категорию, куда не входят эти два крупнейших для проекта источника.

# %%
tiptop_profiles = profiles.query('channel == "TipTop"')
faceboom_profiles = profiles.query('channel == "FaceBoom"')
other_paid_profiles = profiles.query(
    'channel not in ["TipTop", "FaceBoom", "organic"]'
)
organic_profiles = profiles.query('channel == "organic"')

# %%
show(['region'], profiles=other_paid_profiles)

# %% [markdown]
# Оставшиеся три американских источника привлекают пользователей с таким же LTV как европейские. А стоимость привлечения по ним ниже. Узнав это, логичным выглядит средства вместо TipTop направить именно в эти три канала. Они входят в четыре лучших по ROI (это те каналы, которые дают менее качественных, но дешёвых пользователей).

# %% [markdown]
# #### Выводы по странам
#
# - Существуют два различающихся региона:
#   - Европа;
#   - США.
# - Каждый канал привлечения действует только в Европе или только в США.
# - Если не учитывать показатели двух крупнейших и проблемных каналов - то:
#   - США по активности пользователей не отличается от Европы.
#   - Но пользователи США сщественно дешевле европейских.
#
# **Рекомендации**:
#
# - устранить причины падения заказов от пользователей из Британии в августе-сентябре, из Франции в октябре;
# - бюджет, планировавшийся на TipTop, направить в MediaTornado, YRabbit, RocketSuperAds.

# %% [markdown]
# ### Окупаемость по устройствам

# %% [markdown]
# Сразу взглянем на связь между устройством и каналами.

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax = sns.heatmap(
    paid_profiles.pivot_table(
        index='channel',
        columns='device',
        values='user_id',
        aggfunc='nunique',
    ).fillna(0),
    annot=True,
    fmt="d",
    linewidths=1,
    cmap="YlGnBu",
)
plt.show()

# %% [markdown]
# FaceBoom и TipTop привлекают в оновном пользователей Apple (iPhone и Mac). Это касается и других каналов из Америки. Европейские каналы привлекают больше PC и Android.
#
# Проверим это. Сводка по регионам:

# %%
fig, ax = plt.subplots(figsize=(6, 4))
ax = sns.heatmap(
    paid_profiles.pivot_table(
        index='region',
        columns='device',
        values='user_id',
        aggfunc='nunique',
    ).fillna(0),
    annot=True,
    fmt="d",
    linewidths=1,
    cmap="YlGnBu",
)
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# Действительно,
#
# Европейские пользователи приходят примерно поровну с десктопа и с мобильных. Устройств Apple чуть менее трети от всех.
#
# Американские: две трети пользователей впервые входили на мобильниках, более двух третей - Apple.
#
# Оценим окупаемость.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Хорошо, что рассмотрели привязку устройств к каналам и регионам!
# </div>

# %%
show(['device'])

# %% [markdown]
# Стоимость привлечения растёт у Mac и iPhone. Узнаем, что если убрать два худших по ROI канала.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Окупается только PC. Но в динамике видим, что и он с сентября перестает окупаться.
# </div>

# %%
show(['device'], profiles=other_paid_profiles)

# %% [markdown]
# Разница между устройствами по стоимости привлечения - уменьшилась. Динамика стоимости за прошедшее время стала подобной для всех устройств.
#
# Обратим внимание: когда Mac показывает большую LTV - iPhone показывает падение. Это совпадение может раскрыть нам некую связь между пользователями iPhone и Mac? Предположим: есть физические лица, владеющие обоими устройствами, и платящие с того устройства, которое сейчас под руками?

# %% [markdown]
# #### Выводы по устройствам
#
# - разница между метриками устройств несущественна по сравнению с метриками каналов;
#
# **Рекомендации**
#
# - Привлекать больше пользователей Mac и iPhone. PC и Android менее выгодны.
# - Найти причину длительного падения LTV у пользователей Mac в течение лета и в последний месяц;
# - и причину резких взлётов Mac в мае и начале сентября.

# %% [markdown]
# ### Метрики внутри TipTop и FaceBoom.
#
# Мы выбрали четыре категории пользователей:
# - TipTop,
# - FaceBoom,
# - остальные платные,
# - органические.
#
# Исследуем первые две. Как внутри них распределены метрики?

# %% [markdown]
# #### TipTop

# %%
show(['device'], profiles=tiptop_profiles)

# %%
_, conversion, conversion_history = get_conversion(
    tiptop_profiles,
    orders,
    observation_date,
    horizon,
    dimensions=['device'],
)

plot_conversion(conversion, conversion_history, horizon, window=window)

# %% [markdown]
# Пользователи PC и Android на любых лафтаймах совершают заказы охотнее, чем iPhone и Mac.

# %%
_, retention, retention_history = get_retention(
    tiptop_profiles,
    visits,
    observation_date,
    horizon,
    dimensions=['device'],
)

plot_retention(retention, retention_history, horizon, window=window)

# %% [markdown]
# В зависимости от лайфтайма разные утройства показывают лучшие результаты. Целевым считается лайфтайм 13. Посмотриму удержание в этот срок.

# %%
retention[13]
# Out:
# payer  device
# False  Android    0.005186
#        Mac        0.003863
#        PC         0.004678
#        iPhone     0.003956
# True   Android    0.223350
#        Mac        0.242206
#        PC         0.180412
#        iPhone     0.184615
# Name: 13, dtype: float64

# %% [markdown]
# Лучше удерживаются платящие пользователи Mac и Android, хуже - iPhone и PC. С друго стороны, с ростом лайфтайма все эти значения колеблются около некоей средней линии, и на более длительных лайфтаймах удержание может распределиться иначе. Также иначе распределяется удержание среди неплативших пользователей: лучшие Android и PC, а Apple проявляют меньше интереса. Возможно это связано с тем, что пользователи Android и PC чаще ждут некоего события, при котором они готовы сделать первый заказ (например, они ждут скидок, удобств или приманок для заказа).

# %% [markdown]
# #### FaceBoom

# %%
show(['device'], profiles=faceboom_profiles)

# %%
_, conversion, conversion_history = get_conversion(
    faceboom_profiles,
    orders,
    observation_date,
    horizon,
    dimensions=['device'],
)

plot_conversion(conversion, conversion_history, horizon, window=window)

# %%
_, retention, retention_history = get_retention(
    faceboom_profiles,
    visits,
    observation_date,
    horizon,
    dimensions=['device'],
)

plot_retention(retention, retention_history, horizon, window=window)

# %%
retention[13]
# Out:
# payer  device
# False  Android    0.004149
#        Mac        0.004643
#        PC         0.004789
#        iPhone     0.004157
# True   Android    0.005348
#        Mac        0.014118
#        PC         0.027523
#        iPhone     0.011830
# Name: 13, dtype: float64

# %% [markdown]
# Конверсия лучше всего на Android, далее Mac, iPhone и PC. Удержание плохое на всех платформах.

# %% [markdown]
# #### Выводы по проблемным каналам
#
# - На этих каналах конверсия несколько лучше у Mac и Android. Несколько хуже на iPhone и PC.
# - Однако это имеет второстепенное значение, по сравнению с основными проблемами этих каналов:
#   - Высокой цены за привлечение в TipTop.
#   - Низкой конверсии в FaceBoom.

# %% [markdown]
# ### Итоги оценки окупаемости пользователей
#
# - Все профили можно разделить на две большие категории:
#   - европейские:
#     - пользователи из Британии, Франции и Германии
#     - используют в равной мере настольные / мобильные устройства;
#     - приходят только по каналам lambdaMediaAds, AdNonSense, LeapBob, OppleCreativeMedia, WahooNetBanner;
#   - американские;
#     - только из США;
#     - две трети устройств - мобильные, более двух третей - Apple;
#     - приходят только по каналам MediaTornado, YRabbit, RocketSuperAds, FaceBoom, TipTop;
#     - LTV у них как у европейцев,
#     - но CAC отличается:
#       - есть два очень дорогих американских канала,
#       - и три таких, которые существенно дешевле европейских.
#
# - Два канала, на которые были выделены наибольшие бюджеты - являются худшими:
#   - TipTop - по стоимости привлечения (его цена непрерывно росла, скачками каждый месяц);
#   - FaceBoom - по удержанию.
# - Они вносят решающее искажение в статистику,
#   - поэтому по всем признакам приходится считать две статистики - с ними и без них.
# - Треть пользователей поступили по бесплатным каналам, и также искажают статистику
#   - Они скрыли проблемы двух платных каналов.
#
# - По устройствам разница в LTV укладывается в 10%.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Согласен с выводами.
# </div>
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Можно не мельчить оперируя отдельными каналами, вполне достаточно будет рассмотреть рекламу отдельно по странам.
# </div>
#
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Я прихожу к выводу, что разница между каналами больше, чем разница между странами. Поэтому упомянуть названия конкретных каналов важнее, чем конкретных стран.
# </div>
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ⚠️ Тут мы на графиках и так видим проблему по каналам, а если разделить их по регионам - увидим еще, что каналы не пересекаются.
# </div>

# %% [markdown]
# ## Общие итоги
#
# - Исследовано:
#   - выборки с 1 мая по 27 октября 2019 года;
#     - 150 тыс профилей пользователей;
#     - 310 тыс визитов;
#     - 40 тыс покупок от 8,9 тыс пользователей;
#   - деловые метрики:
#     - окупаемость инвестиций ROI,
#     - цена привлечения пользователя CAC,
#     - конверсия в плательщики CR,
#     - удержание пользователя Retention Rate.
#   - разделение пользователей на группы по признакам:
#     - каналы (источники пользователей);
#     - страны,
#     - используемые устройства.
#
# - **Установлено**:
#   - Низкая окупаемость связана с двумя фактами:
#     - Уходом с ресурса платящих пользователей, приходящих через FaceBoom;
#     - Высокой ценой привлечения пользователей через TipTop.
#   - Возникновение убытков связано с одним фактом:
#     - Ежемесячным фиксированным повышением и без того высокой цены привлечения через TipTop.
#
# - **Рекомендации, как вернуться к прибыли**:
#   - Главные:
#     - Расходы, предназначенные для TipTop, направить в MediaTornado, YRabbit, RocketSuperAds.
#     - Выяснить, почему платившие пользователи, пришедшие с FaceBoom, скоро после первого посещения перестают посещать ресурс;
#   - Дополнительные:
#       - Отдавать предпочтение пользователям:
#         - Apple;
#         - десктопов.
#       - Выяснить причину перепадов удержания:
#         - среди британцев;
#         - среди пользователей Mac.
#         - это может помочь повторить взлёты удержания и избежать его падения.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Отличные общие выводы и рекомендации! 🔥 Маркетологи оценят! 🙂
# </div>

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
#
#
#   <b>Чек-лист доработок</b>
#
#   📃 Проект выполнен без критических замечаний! Не принимаю сразу на случай, если у тебя есть какие-то вопросы. Не стесняйся оставлять комментарии и спрашивать! Если вопросов нет - просто отправляй проект на проверку и я его сразу приму.
# </div>
#
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Вопросы по проекту:
#
#   - хотелось сделать heatmap, в котором будет не общая шкала градаций, а индивидуальна шкала на каждый столбик. Вижу путь - делать цикл: отдельный хитмэп на каждый столбик. И разместить их на одном холсте. Может, есть проще что-то?
#   - В выводе хотел описать, что будет, если мои выводы оправдаются. Сколько потенциальных клиентов, выручки можно получить, если финансировать наилучшие каналы, и если каналы не изменятся при этом. Такие прогнозы - оправданы?
#   - Рекламные каналы имеют одинаковую эффективность при разном количестве затрат? Если мы в выгодный канал внесём по-настоящему много денег - то при росте он может ухудшиться, улучшиться, остатья прежним, или результат непредсказуем?
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <b>Комментарий ревьюера v.2</b>
#
# - Зачем такие заморочки с хитмапом? Это вообще не самый удачный тип графика, идет, скорее, по привычке после екселя. Дальше будет спринт (Как рассказать историю с помощью данных) там покажут разные типы графиков.
#
# - Предсказания тут это, разве что, применить ML, и то не уверен, что за наш период в полгода мы что-то дельное сможем предсказать. Надо хотя-бы за пару лет выборку.
#
# - Результат не предсказуем, в мае TipTop казался перспективным, в него начали вкладывать деньги и какой результат? Тут обязательно нужно мониторить, что мы получаем, а не увеличивать бюджет в течении полугода.
# </div>
