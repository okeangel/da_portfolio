# %% [markdown]
# # Предприятия общественного питания в Москве

# %% [markdown]
# Учебный проект по специальности "аналитик данных", 21-я неделя обучения.
# Тема: Сторителлинг по данным.
#
# Автор: Александр Лагутин.
#
# Начат: 25 октября 2022 г в 08:30.
# Завершён: 0 месяца 2022 г в 00:00.
#
# Время подготовки: 0 рабочих часов (0 рабочих дня).
#
# - 2 часа - оформление плана работ.
# - 2 часа 30 минут - удаление неявных повторов.
# - 1 час - другая подготовка данных.

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span><ul class="toc-item"><li><span><a href="#Заказчик" data-toc-modified-id="Заказчик-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Заказчик</a></span></li><li><span><a href="#Задача" data-toc-modified-id="Задача-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Задача</a></span></li><li><span><a href="#Входные-данные" data-toc-modified-id="Входные-данные-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Входные данные</a></span><ul class="toc-item"><li><span><a href="#Термины" data-toc-modified-id="Термины-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Термины</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Описание данных</a></span><ul class="toc-item"><li><span><a href="#Предприятия-питания-places" data-toc-modified-id="Предприятия-питания-places-1.3.2.1"><span class="toc-item-num">1.3.2.1&nbsp;&nbsp;</span>Предприятия питания <code>places</code></a></span></li></ul></li></ul></li><li><span><a href="#План-работы" data-toc-modified-id="План-работы-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>План работы</a></span></li><li><span><a href="#Инструменты" data-toc-modified-id="Инструменты-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Инструменты</a></span><ul class="toc-item"><li><span><a href="#Импорт-библиотек" data-toc-modified-id="Импорт-библиотек-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Импорт библиотек</a></span></li><li><span><a href="#Определения-констант" data-toc-modified-id="Определения-констант-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>Определения констант</a></span></li><li><span><a href="#Определения-функций" data-toc-modified-id="Определения-функций-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>Определения функций</a></span><ul class="toc-item"><li><span><a href="#Загрузка-и-обзор-данных" data-toc-modified-id="Загрузка-и-обзор-данных-1.5.3.1"><span class="toc-item-num">1.5.3.1&nbsp;&nbsp;</span>Загрузка и обзор данных</a></span></li><li><span><a href="#Исправление-данных" data-toc-modified-id="Исправление-данных-1.5.3.2"><span class="toc-item-num">1.5.3.2&nbsp;&nbsp;</span>Исправление данных</a></span></li><li><span><a href="#Отображение-данных" data-toc-modified-id="Отображение-данных-1.5.3.3"><span class="toc-item-num">1.5.3.3&nbsp;&nbsp;</span>Отображение данных</a></span></li><li><span><a href="#A/B-test" data-toc-modified-id="A/B-test-1.5.3.4"><span class="toc-item-num">1.5.3.4&nbsp;&nbsp;</span>A/B-test</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Пропуски-в-данных" data-toc-modified-id="Пропуски-в-данных-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Пропуски в данных</a></span></li><li><span><a href="#Преодоление-неявных-и-явных-дубликатов" data-toc-modified-id="Преодоление-неявных-и-явных-дубликатов-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Преодоление неявных и явных дубликатов</a></span></li><li><span><a href="#Верные-типы-данных" data-toc-modified-id="Верные-типы-данных-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Верные типы данных</a></span></li><li><span><a href="#Добавляем-street" data-toc-modified-id="Добавляем-street-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Добавляем <code>street</code></a></span></li><li><span><a href="#Добавляем-is_continuous" data-toc-modified-id="Добавляем-is_continuous-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Добавляем <code>is_continuous</code></a></span></li><li><span><a href="#Итоги-подготовки-данных" data-toc-modified-id="Итоги-подготовки-данных-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Итоги подготовки данных</a></span></li></ul></li><li><span><a href="#Обобщённые-данные-о-предприятиях-питания" data-toc-modified-id="Обобщённые-данные-о-предприятиях-питания-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Обобщённые данные о предприятиях питания</a></span><ul class="toc-item"><li><span><a href="#Типы-предприятий" data-toc-modified-id="Типы-предприятий-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Типы предприятий</a></span></li><li><span><a href="#Распределение-по-расписанию-работы" data-toc-modified-id="Распределение-по-расписанию-работы-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Распределение по расписанию работы</a></span></li><li><span><a href="#Итоги-подготовки-информации-о-расходах:" data-toc-modified-id="Итоги-подготовки-информации-о-расходах:-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Итоги подготовки информации о расходах:</a></span></li></ul></li><li><span><a href="#Портрет-желаемой-кофейни" data-toc-modified-id="Портрет-желаемой-кофейни-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Портрет желаемой кофейни</a></span><ul class="toc-item"><li><span><a href="#Итоги-анализа-расходов" data-toc-modified-id="Итоги-анализа-расходов-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Итоги анализа расходов</a></span></li></ul></li><li><span><a href="#Общие-итоги" data-toc-modified-id="Общие-итоги-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общие итоги</a></span></li></ul></div>

# %% [markdown]
# ## Описание проекта
#
# ### Заказчик
#
# Инвесторы из фонда «Shut Up and Take My Money».
#
# ### Задача
#
# Составить описание предприятий общественного питания в Москве. Расположение, тип, меню, цены.
#
# Составить лаконичную презентацию.
#
# Для чего: чтобы выбрать, какое предприятие питания и где открыть.

# %% [markdown]
# ### Входные данные
#
# Датасет предприятий общепита Москвы из Яндекс.Карт и Яндекс.Бизнеса на лето 2022 года. Информация добавлена пользователями, частично - представителями предприятий, а также собрана автоматически из открытых источников Сети.
#
# #### Термины
#
# При постановке задачи употреблялось слово "заведение". Поскольку речь пойдёт о бизнесе, по-русски - о предпринимательстве, то назовём "заведения" предприятиями. Это слово лучше всего отражает суть: предприятие общепита инвестор воспринимает как что-то, что можно "сделать", предпринять, чтобы заработать. Верные формулировки направят нас к верным выводам.
#
# "Чеком" в общепите часто называют не сам оформленный чековый документ, а стоимость заказа. Мы будем употреблять "стоимость заказа", поскольку смысл тот же, и понятно всем.
#
# #### Описание данных
#
# ##### Предприятия питания `places`
#
# - `name` - название;
# - `address` - почтовый адрес;
# - `category` - тип;
# - `hours` - расписание работы;
# - `lat` - широта расположения;
# - `lng` - долгота расположения;
# - `rating` - оценка пользователей Яндекса (высшая - 5.0)
# - `price` - категория цен;
# - `avg_bill` - диапазон средней стоимости заказа, заказы бывают своего типа у каждого типа предприятия (бокал пива, чашка капучино);
# - `middle_avg_bill` - средняя цена заказа в общем (если в `avg_bill` указан именно "Средний счёт")
# - `middle_coffee_cup` - средняя цена чашки капучино (если в `avg_bill` указана "Цена одной чашки капучино")
# - `chain` - входит ли предприятие в коммерческую сеть (для малых сетей "могут встречаться ошибки" - видимо, предприятия малой сети могут быть отмечены как не входящие в неё, как самостоятельные),
# - `district` - городской округ, к которому относится предприятие;
# - `seats` - количество посадочных мест.

# %% [markdown]
# ### План работы
#
# Действия:
# - [x] Импортировать библиотеки, описать функции, которые потребуются:
#   - [x] для расчёта и диаграмм;
#   - [x] для отображения геолокации.
# - [x] Загрузить и изучить таблицы.
# - [x] Подготовить данные:
#   - [x] привести к норме названия столбцов;
#   - [x] обработать дубликаты:
#     - [x] неявные дубликаты значений;
#     - [x] полные дубликаты строк;
#   - [x] привести данные к нужным типам;
#   - [x] обработать пропуски:
#     - [x] выбрать, чем заполнить (или оставить) и почему;
#     - [x] осуществить заполение, если требуется;
#     - [x] описать причины, которые могли привести к пропускам.
#   - [x] Добавить данные:
#     - [x] столбец `street` - названия улиц (из адресов);
#     - [x] столбец `is_24/7` (`bool`) - предприятие непрерывной работы (24 часа в сутки, 7 дней в неделю).
# - [ ] Анализировать обобщённые данные:
#   - [ ] Какие типы предприятий есть, как распределены? Визуализация этого. Выводы.
#   - [ ] Сколько посадочных мест у предприятий каждого типа? Визуализации распределений. Выводы.
#   - [ ] Сетевые и самостоятельные предприятия. Каких больше?
#   - [ ] В каких категориях сетевые встречаются чаще? Визуализация. Выводы.
#   - [ ] Группируем по названиям, чтобы получить 15 самых "популярных" сетей в Москве. (Нужно описать, как оценим "популярность" сети. Это может быть количество предприятий (очень коственный признак популярности), либо количество оценок, либо ещё что-то.) Знакомы ли эти наименования? Что их объединяет? Визуализация количества предприятий каждой сети по округам города.
#   - [ ] Какие районы описаны в данных? Общее количество предприятий, и количество предприятий каждой категории по районам. Единая диаграмма - stacked bars.
#   - [ ] Средний рейтинг по категориям предприятий. Сильно ли они различаются? Возможна статистическая проверка гипотезы.
#   - [ ] Фоновая картограмма среднего рейтинга предприятий каждого района.
#   - [ ] Кластерная карта предприятий общепита Москвы.
#   - [ ] 15 улиц, на которых больше всего предприятий питания. Диаграмма: какие категории как представлены на этих улицах. Stacked bars.
#   - [ ] Улицы, на которых по одной точке питания. Что схожего у этих предприятий?
#   - [ ] Медиана средних стоимостей для каждого округа. Картограмма стоимости. Как влияет удалённость от центра города на стоимость?
#   - [ ] Какие ещё найдены взаимосвязи? Связь режима работы, расположения и типа предприятия. Связь плохого рейтинга, средней стоимости заказа и категорий.
#   - [ ] Описать выводы по обобщённым данным.
# - [ ] Идея инвесторов: "крутая" и "доступная" кофейня в Москве (как "Central Perk" в сериале "Друзья"). Конкуренция не считается препятствием. Какие могут быть ные препятствия?
#   - [ ] Сколько всего кофеен? В каких районах их больше? Где они размещатся?
#   - [ ] Существуют ли круглосуточные кофейни?
#   - [ ] Какие у них рейтинги? Как распределены рейтинги кофеен по районам?
#   - [ ] Какую стоимость чашки капучино следует установить и почему?
#   - [ ] Какие ещё признаки добавить в описание?
#   - [ ] В качестве вывода - описать рекомендации.
#  [ ] Создать презентацию в PDF, разместить её в облаке, ссылку в ячейке.
#   - [ ] что исследовано (указать основные зарактеристики данных);
#   - [ ] какие ответы на основные вопросы исследования;
#   - [ ] какие гипотезы подтвердились или не подтвердились, отвергнуты;
#   - [ ] какие факты обнаружены;
#   - [ ] какие предположения выдвинуты;
#   - [ ] какие есть рекомендации:
#     - [ ] кому,
#     - [ ] суть рекомендации.

# %% [markdown]
# ### Инструменты
#
# Используем [Anaconda](https://www.anaconda.com/), окружение `ds_da_practicum_env.yml` "для Mac OS" (от 2022-03-23).

# %% [markdown]
# #### Импорт библиотек

# %%
# %matplotlib inline

import datetime
import re
import urllib
import json

import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
import folium

# %% [markdown]
# #### Определения констант

# %%
# set size for all charts
FIGSIZE = (10, 5)

# %% [markdown]
# #### Определения функций
#
# ##### Загрузка и обзор данных

# %%
def load(name, ext='csv', sep=','):
    """Return pandas DataFrame by filename"""
    filename = name + '.' + ext
    try:
        df = pd.read_csv(filename)
    except FileNotFoundError:
        df = pd.read_csv('https://code.s3.yandex.net/datasets/' + filename, sep=sep)
    correct_column_names(df)
    overview(df)
    return df

# %%
def overview(data):
    """Display an overview of the data to detect common data problems"""
    display(data.sample(5))
    dupes = data.duplicated().sum()
    dupes_rate = dupes / len(data)
    print(f'Полностью совпадающих строк: {dupes} ({dupes_rate:.2%})\n')
    data.info()
    display(count_nans(data))
    print(get_filled_rows_share(data))

# %%
def count_nans(data):
    """Return a pandas DataFrame with the number of missing values"""
    nans = []
    for column in data.columns:
        # count the number of missing values
        missing = data[column].isna().sum()
        # calculate the share of missing values
        part = round(missing * 100 / len(data), 2)
        # count the number of distinct values
        uniques = data[column].sort_values().nunique()
        nans.append([column, missing, part, uniques])

    return pd.DataFrame(
        data=nans, columns=['column', 'na_count', 'na_%', 'unique_count']
    ).sort_values(['na_count', 'unique_count'], ascending=False).set_index('column')

# %%
def get_filled_rows_share(df):
    """Return a string containing number of rows with no missing values"""
    share = 1 - df.isna().any(axis=1).sum() / len(df)
    return f'Заполненных строк без пропусков: {share:.02%}'

# %% [markdown]
# ##### Исправление данных

# %%
def correct_column_names(df):
    """Convert column names to valid snake_case in place"""
    df.columns = df.columns.str.strip()
    df.columns = list(map(to_snake_case, df.columns))

def to_snake_case(name):
    """Return name converted to valid snake_case"""    
    name = re.sub('(.)([A-Z][a-z]+)', r'\1_\2', name)
    name = re.sub('__([A-Z])', r'_\1', name)
    name = re.sub('([a-z0-9])([A-Z])', r'\1_\2', name)
    return name.lower()

# %%
def fillnaby(df, column, groupby, func='median'):
    """Fill in missing values with group-aggregated values in-place"""
    df[column] = df[column].fillna(
        df.groupby(groupby)[column].transform(func))

# %% [markdown]
# ##### Отображение данных

# %%
def headline(line, width=79):
    """Return the string in plain uppercase text with pseudographics"""
    return f'\n{line.upper():=^{width}}'

# %% [markdown]
# ##### A/B-test

# %%
def center_percentile(data, percentile):
    low = np.percentile(data, (100 - percentile) / 2)
    high = np.percentile(data, (100 + percentile) / 2)
    return low, high

# %% [markdown]
# ## Подготовка данных

# %%
places = load('moscow_places')
# Out:
#                        name         category  \
# 7809                Изи Паб          бар,паб
# 8345             Цицинатела         булочная
# 331                      Юг         ресторан
# 2357  Мороженое 18+ Alcreme          кофейня
# 7364                 Шаурма  быстрое питание
#
#                                                 address  \
# 7809                       Москва, Каширское шоссе, 122
# 8345                    Москва, Вешняковская улица, 18Б
# 331   Москва, Северный административный округ, Голов...
# 2357                  Москва, проспект Мира, 26, стр. 1
# 7364                    Москва, Люблинская улица, 171к1
#
#                                   district  \
# 7809          Южный административный округ
# 8345      Восточный административный округ
# 331        Северный административный округ
# 2357    Центральный административный округ
# 7364  Юго-Восточный административный округ
#
#                                                   hours        lat        lng  \
# ...

# %% [markdown]
# ### Пропуски в данных

# %% [markdown]
# Полностью заполненных строк - нет. Менее 7% записей содержат цену чашки капучино. Другие цены тоже чаще не указаны. Почти половина точек - без указания количества мест.
#
# При таком количестве пропусков любое их заполнение решительно повлияет на выводы. Лучше убирать отсутствующие результаты при анализе.
#
# Признак "входит в сеть" заполнен, но "может содержать ошибки" - это хуже чем если бы содержал пропуски, ошибки сложнее обнаружить.
#
# Часы работы содержат данные, которые требуется парсить, и затруднительно сказать, какими значениями заполнить остутствующие расписания работы. Прямолинейные статистические методы тут не принесут пользы.
#
# Таким образом, заполнять пропуски представляется не нужным.
#
# Мы можем полагаться на геоданные (координаты, адреса, округа), названия, рейтинг.

# %% [markdown]
# ### Преодоление неявных и явных дубликатов

# %% [markdown]
# Бытовая привычка говорит нам, что если название двух объектов одинаково или слишком похоже - то это одинаковые объекты, например, представители одной сети. Юристы и другие специалисты могут напомнить, что это не всегда так. Вполне могу существовать два предприятия с одинаковыми названиями, никак не связанные между собой. И степень связанности может быть разной - общая администрация, общее юрлицо, общий владелец, общая франшиза, стихийное использование общего громкого названия (особенно если оно не защищено юридически). Поэтому сложно сказать, что именно мы будем считать сетью. Опираться только на названия - не очень надёжно.
#
# Также учитываем, что названия могут быть написаны по-разному просто по стечению обстоятельств. Например, названия предприятий Яндекса записаны в разных источниках по разному, то с точкой, то без неё. Названия записаны по-разному, но предприятия Яндекса определённо не самостоятельны, а объединены.
#
# Основной смысл несут буквы и числа. Именно они произносятся, именно они составляют речь. Пробелы, знаки препинания, служебные символы, регистр - важны гораздо меньше, и именно они обычно различаются при написании названия одного и того же объекта, поскольку в речи они трудно различимы.
#
# Поэтому уникальность строки будем определять не по всему её содержимому, а только оставив в строке буквы и цифры, без всего, без пробелов. Это тоже вполне читаемый текст, это и есть суть текста, суть названия.
#
# Если строка содержит те же буквы и цифры в том же порядке, как другая строка - они считаются одинаковыми. Сперва поищем, сколько одинаковых по смыслу строк в текстовых столбцах.

# %%
def get_meaning_pattern(text):
    # имеющими значение будем считать только буквы и цифры
    return ''.join(char for char in text.lower() if char.isalpha() or char.isdigit())

# проверяем все текстовые поля,
# есть ли в них строки, различающиеся не смыслом, а формой записи
for column in places.select_dtypes(include='object').columns:
    values = places[column].dropna().unique()
    patterns = set(map(get_meaning_pattern, values))
    if len(patterns) != len(values):
        print('Столбец {} содержит неодинаковое количество различных значений:\n'
              'по смыслу их {} разных, по форме записи {} разных'.format(
                  column, len(patterns), len(values)))
        print(values + '\n')
# Out:
# Столбец name содержит неодинаковое количество различных значений:
# по смыслу их 5454 разных, по форме записи 5614 разных
# ['WoWфли\n' 'Четыре комнаты\n' 'Хазри\n' ... 'Миславнес\n' 'Самовар\n'
#  'Kebab Time\n']
# Столбец address содержит неодинаковое количество различных значений:
# по смыслу их 5750 разных, по форме записи 5753 разных
# ['Москва, улица Дыбенко, 7/1\n' 'Москва, улица Дыбенко, 36, корп. 1\n'
#  'Москва, Клязьминская улица, 15\n' ...
#  'Москва, улица Лобачевского, 52, корп. 1\n'
#  'Москва, Болотниковская улица, 52, корп. 2\n'
#  'Москва, Чонгарский бульвар, 26А, корп. 1\n']

# %% [markdown]
# Подготовим функцию, которая, получив строку таблицы, возвращает текст из выбранной колонки. Если ранее уже встречалась другая формулировка этого же текста - то вернёт ту, ранее встречавшуюся. Смыслы и соответствующие им формулировки накапливаются во внешнем словаре. Поэтому перед использованием функции словарь надо создавать (пустым).

# %%
def get_mean_text(row, column):
    pattern = get_meaning_pattern(row[column])    
    if pattern in patterns.keys() and row[column] != patterns[pattern]:
        print(f"{row[column]} -> {patterns[pattern]}")
        return patterns[pattern]
    else:
        patterns[pattern] = row[column]
        return row[column]

# %% [markdown]
# Проверка на уникальность показала, что 'names' и 'addresses' содержат неявные дубликаты. Поскольку дальнейшие исследования будут использовать названия - то исходные столбцы менять не будем, а добавим дополнительные 2 столбца, с "подразумеваемыми" названиями и адресами.

# %%
patterns = dict()
column = 'name'
places[f'mean_{column}'] = places.apply(
    lambda row: get_mean_text(row, column), axis=1)
# Out:
# Хинкали-Gали! -> Хинкали Gали!
# Хинкали-Gали! -> Хинкали Gали!
# Доминос пицца -> Домино'с Пицца
# Хинкали-Gали! -> Хинкали Gали!
# Meat Лав -> MeatЛав
# Донер кебаб -> Донер Кебаб
# Чай хана халал -> Чайхана Халал
# В парке вкуснее! -> В парке вкуснее
# Кафе-бар -> Кафе бар
# Чайхона №1 -> Чайхона № 1
# Кафе-Столовая -> Кафе-столовая
# Кафе-бар -> Кафе бар
# МСК lounge -> МСК Lounge
# Хинкали Gали -> Хинкали Gали!
# Франклинс бургер -> Франклинс Бургер
# Wild Bean Cafe -> Wild bean cafe
# Wild Bean Cafe -> Wild bean cafe
# Яндекс.Лавка -> Яндекс Лавка
# Wild Bean Cafe -> Wild bean cafe
# Чайхана халяль -> Чайхана Халяль
# Новая столовая -> Новая Столовая
# More Poke -> More poke
# Кафе-бар -> Кафе бар
# SeDelice -> Sedelice
# Shake up -> ShakeUp
# Pho Bo -> PhoBo
# Хинкали - Gали! -> Хинкали Gали!
# Ача-Чача -> Ача-чача
# Важная Персона -> Важная персона
# Jeffrey's Coffeeshop -> Jeffrey’s Coffeeshop
# It's СоТ-Кофейня -> It's СоТ - Кофейня
# Лепим и Варим -> Лепим и варим
# ...

# %%
patterns = dict()
column = 'address'
places[f'mean_{column}'] = places.apply(
    lambda row: get_mean_text(row, column), axis=1)
# Out:
# Москва, парк Ангарские Пруды -> Москва, парк Ангарские пруды
# Москва, Кутузовский проспект, 17 -> Москва, Кутузовский проспект, 1/7
# Москва, Кутузовский проспект, 17 -> Москва, Кутузовский проспект, 1/7
# Москва, Кутузовский проспект, 17 -> Москва, Кутузовский проспект, 1/7
# Москва, улица Академика Варги, 8 к 1 -> Москва, улица Академика Варги, 8к1
# Москва, улица Академика Варги, 8 к 1 -> Москва, улица Академика Варги, 8к1

# %%
print('Различных названий:', len(places[f'mean_{column}'].unique()))
# Out:
# Различных названий: 5750

# %%
print('Различных адресов:', len(places[f'mean_{column}'].unique()))
# Out:
# Различных адресов: 5750

# %% [markdown]
# Полученные адреса и названия различны не только по форме, но и по смыслу. Поэтому посчитаем дубликаты ещё раз, считая уникальным сочетание подразумеваемого названия и подразумеваемого адреса.

# %%
places[places[['mean_name', 'lat', 'lng']].duplicated()][['mean_name', 'lat', 'lng']]
# Out:
#       mean_name        lat        lng
# 1511  More poke  55.806307  37.497566

# %%
dupes = places[
    places[['mean_name', 'mean_address']].duplicated()
][['mean_name', 'mean_address']]

display(dupes)
# Out:
#                       mean_name  \
# 215                        Кафе
# 600             В парке вкуснее
# 1511                  More poke
# 2420  Раковарня Клешни и Хвосты
# 3109            Хлеб да Выпечка
# 4780                    Cafe 13
#
#                                            mean_address
# 215                        Москва, парк Ангарские пруды
# 600   Москва, Северный административный округ, район...
# 1511            Москва, Волоколамское шоссе, 11, стр. 2
# 2420                         Москва, проспект Мира, 118
# 3109                        Москва, Ярцевская улица, 19
# 4780               Москва, Мясницкая улица, 13, стр. 11

# %% [markdown]
# Видим, что вместе с записью 1511 - у нас 6 дубликатов. Убедимся, что это одни и те же рестораны, упомянутые дважды. Кроме того, взглянем, какую информацию можно объединить из двух строк в одну.

# %%
def select_rows(keys):
    display(places[
        (places['mean_name'] == keys['mean_name'])
        & (places['mean_address'] == keys['mean_address'])
    ])

dupes.apply(select_rows, axis=1)
# Out:
#      name category                       address  \
# 189  Кафе     кафе  Москва, парк Ангарские Пруды
# 215  Кафе     кафе  Москва, парк Ангарские пруды
#
#                             district                   hours        lat  \
# 189  Северный административный округ  ежедневно, 09:00–23:00  55.880327
# 215  Северный административный округ  ежедневно, 10:00–22:00  55.881438
#
#            lng  rating price avg_bill  middle_avg_bill  middle_coffee_cup  \
# 189  37.530786     3.2   NaN      NaN              NaN                NaN
# 215  37.531848     3.2   NaN      NaN              NaN                NaN
#
#      chain  seats mean_name                  mean_address
# 189      0    NaN      Кафе  Москва, парк Ангарские пруды
# 215      0    NaN      Кафе  Москва, парк Ангарские пруды
#                  name category  \
# 599  В парке вкуснее!     кафе
# 600   В парке вкуснее  кофейня
#
#                                                address  \
# ...

# %% [markdown]
# В каждой паре записей совпадают рейтинги и количество мест. Дистанция между ними по координатам - от нескольких метров до нескольких сотен метров. Сравнив данные с информацией, предоставляемой сейчас пользователям Яндекс.Картами, не удаётся определить, кака информация актуальнее - в каждом случае на картах присутствуют обе записи. Получать срежднюю величину из пары, поэтому удаляем первые результаты - скорее всего, они старше и менее актуальны.

# %%
places = places.drop([189, 599, 1430, 2211, 3091, 4613]).reset_index(drop=True)

# %% [markdown]
# ### Верные типы данных
#
# Количество мест должно быть целым числом.

# %%
places['seats'] = places['seats'].astype({'seats': 'Int64'})
places.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8400 entries, 0 to 8399
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               8400 non-null   object
#  1   category           8400 non-null   object
#  2   address            8400 non-null   object
#  3   district           8400 non-null   object
#  4   hours              7864 non-null   object
#  5   lat                8400 non-null   float64
#  6   lng                8400 non-null   float64
#  7   rating             8400 non-null   float64
#  8   price              3315 non-null   object
#  9   avg_bill           3816 non-null   object
#  10  middle_avg_bill    3149 non-null   float64
#  11  middle_coffee_cup  535 non-null    float64
#  12  chain              8400 non-null   int64
#  13  seats              4791 non-null   Int64
#  14  mean_name          8400 non-null   object
#  15  mean_address       8400 non-null   object
# ...

# %% [markdown]
# ### Добавляем `street`
#
# ... чтобы проанализировать, на каких улицах есть общепит.

# %%
street_attributes = [
    'улица', 'ул.', 'просп', 'проезд', 'бул.', 'бульвар', 'б-р',
    'шоссе', 'площ',
]

def get_street(place):
    addr = place['address'].split(', ')

    # иногда в адресах вторым идёт какой-нибудь район или посёлок,
    # а в конце идёт не только дом, но и строение,
    # поэтому будем искать улицу не по позиции в адресе,
    # а очевидным способом - по упоминанию слова "улица" или аналогичного
    for part in addr:
        for attr in street_attributes:
            if attr in part:
                return part

    # если не найдём - вернём второй элемент адреса
    return addr[1]

places['street'] = places.apply(get_street, axis=1)
places.sample(10)[['address', 'street']]
# Out:
#                                                 address  \
# 6101                     Москва, улица Вавилова, 64/1с1
# 1604                      Москва, Хорошёвское шоссе, 27
# 3913                      Москва, Украинский бульвар, 5
# 3344                  Москва, Малая Филёвская улица, 22
# 2939      Москва, Большая Семёновская улица, 20, стр. 2
# 1830                       Москва, Ходынский бульвар, 2
# 5000                     Москва, Пятницкая улица, 25с1Д
# 1484  Москва, улица Зои и Александра Космодемьянских...
# 4103                  Москва, Кропоткинский переулок, 8
# 4865      Москва, Верхняя Радищевская улица, 15, стр. 2
#
#                                       street
# 6101                          улица Вавилова
# 1604                       Хорошёвское шоссе
# 3913                      Украинский бульвар
# 3344                   Малая Филёвская улица
# 2939               Большая Семёновская улица
# 1830                       Ходынский бульвар
# ...

# %% [markdown]
# ### Добавляем `is_continuous`
#
# ... чтобы проверить, выделяются ли рестораны, работающие без перерывов, чем-нибудь особенным.

# %%
# NaN по умолчанию превращается в False
places['is_continuous'] = places['hours'] == 'ежедневно, круглосуточно'
# А нужно, чтобы оставался третий вариант - "неизвестно"
places.loc[places['hours'].isna(), 'is_continuous'] = None

places[['hours', 'is_continuous']].sample(10)
# Out:
#                                                   hours  is_continuous
# 548                              ежедневно, 10:00–22:00            0.0
# 1259  пн-пт 06:30–21:30; сб 07:30–21:30; вс 08:30–21:30            0.0
# 6360                             ежедневно, 10:00–22:00            0.0
# 2113               пн-пт 09:00–23:00; сб,вс 10:00–23:00            0.0
# 5066               пн-пт 10:00–22:00; сб,вс 10:00–23:00            0.0
# 2453                                                NaN            NaN
# 6781                             ежедневно, 08:00–20:00            0.0
# 4600                                  пн-пт 09:00–18:00            0.0
# 2357                             ежедневно, 09:00–23:00            0.0
# 3417               пн-пт 10:00–00:00; сб,вс 12:00–00:00            0.0

# %% [markdown]
# ### Итоги подготовки данных
#
# - удалено 6 дубликатов;
# - зафиксированы пропуски в столбцах: middle_coffee_cup (93.64%), middle_avg_bill (62.54%), price (60.56%), avg_bill (54.60%), seats	(42,96%), и относительно мало пропусков в hours (6,38%);
# - добавлены столбцы `street` и `is_continuous`.

# %%
places.sample(5)
# Out:
#             name         category                                address  \
# 7853      Шаурма  быстрое питание         Москва, МКАД, 30-й километр, 6
# 6847       Бедия         ресторан  Москва, Херсонская улица, 20, корп. 1
# 3426  Aq Kitchen         ресторан   Москва, Большая Грузинская улица, 69
# 3528    Брюс бар          бар,паб        Москва, Брюсов переулок, 2/14с1
# 6961     Минутка         булочная    Москва, Нагорная улица, 32, корп. 1
#
#                                  district                   hours        lat  \
# 7853         Южный административный округ                     NaN  55.574039
# 6847  Юго-Западный административный округ  ежедневно, 11:00–22:00  55.652774
# 3426   Центральный административный округ  ежедневно, 11:00–23:00  55.774082
# 3528   Центральный административный округ       вт-вс 17:00–23:00  55.757968
# 6961  Юго-Западный административный округ       пн-сб 09:00–21:00  55.674582
#
# ...

# %% [markdown]
# ## Обобщённые данные о предприятиях питания

# %% [markdown]
# ### Типы предприятий

# %%
places.groupby('category').agg({'name': 'count'}).plot.bar(
    figsize=FIGSIZE, rot=45, title='Количество ')
# Out:
# <AxesSubplot:xlabel='category'>

# %%
sns.set_palette('CMRmap')

plt.figure(figsize=FIGSIZE)
sns.countplot(data=places, x='category')
plt.show()

# %% [markdown]
# ### Распределение по расписанию работы

# %%
common_hours = (
    places.groupby('hours').agg({'name': 'count'})
    .rename(columns={'name': 'count'})
    .sort_values('count', ascending=False)
)

common_hours.head(10)
# Out:
#                           count
# hours
# ежедневно, 10:00–22:00      759
# ежедневно, круглосуточно    730
# ежедневно, 11:00–23:00      396
# ежедневно, 10:00–23:00      310
# ежедневно, 12:00–00:00      253
# ежедневно, 09:00–21:00      203
# ежедневно, 09:00–22:00      183
# ежедневно, 12:00–23:00      178
# ежедневно, 08:00–23:00      160
# ежедневно, 08:00–22:00      148

# %% [markdown]
# ### Итоги подготовки информации о расходах:
#
# - Первый;
# - Второй;
# - Третий.

# %%
district_boundaries = json.loads(urllib.request.urlopen(
    'https://code.s3.yandex.net/data-analyst/admin_level_geomap.geojson'
).read())

# %% [markdown]
# ## Портрет желаемой кофейни

# %% [markdown]
# ### Итоги анализа расходов
#
# - Первый;
# - Второй;
# - Третий.

# %% [markdown]
# ## Общие итоги
#
# - Исследовано:
# - **Подтверждённые выводы:**
# - Также обнаружено, что:
# - Предположения:
